# %%
pip install lxml
# Out:
# Collecting lxmlNote: you may need to restart the kernel to use updated packages.
#   Downloading lxml-4.6.4-cp39-cp39-win_amd64.whl (3.5 MB)
# Installing collected packages: lxml
# Successfully installed lxml-4.6.4
# WARNING: You are using pip version 21.2.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\Users\Pako\Desktop\realestate-api-final\env\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import requests
from time import sleep
from datetime import datetime
import lxml.html
import pandas as pd

# %%
headers={'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.69 Safari/537.36'}

# %%
url = 'https://zelezna.sk/ponuka-bytov/'
res = requests.get(url, headers=headers)
# print(res.status_code)

tree = lxml.html.fromstring(res.text)
links = tree.xpath('//div[@class="work-item style-5"]/a/@href')
links
# Out:
# ['https://zelezna.sk/byty/c-12-apartman-c5-1/',
#  'https://zelezna.sk/byty/a-9-apartman-a5-1/',
#  'https://zelezna.sk/byty/c-11-apartman-c4-3/',
#  'https://zelezna.sk/byty/c-10-apartman-c4-2/',
#  'https://zelezna.sk/byty/c-9-apartman-c4-1/',
#  'https://zelezna.sk/byty/b-12-byt-b4-3/',
#  'https://zelezna.sk/byty/b-11-byt-b4-2/',
#  'https://zelezna.sk/byty/b-10-byt-b4-1/',
#  'https://zelezna.sk/byty/a-8-apartman-a4-2/',
#  'https://zelezna.sk/byty/a-7-apartman-a4-1/',
#  'https://zelezna.sk/byty/c-8-apartman-c3-3/',
#  'https://zelezna.sk/byty/c-7-apartman-c3-2/',
#  'https://zelezna.sk/byty/c-6-apartman-c3-1/',
#  'https://zelezna.sk/byty/b-9-byt-b3-3/',
#  'https://zelezna.sk/byty/b-8-byt-b3-2/',
#  'https://zelezna.sk/byty/b-7-byt-b3-1/',
#  'https://zelezna.sk/byty/a-6-apartman-a3-2/',
#  'https://zelezna.sk/byty/a-5-apartman-a3-1/',
#  'https://zelezna.sk/byty/c-5-apartman-c2-3/',
#  'https://zelezna.sk/byty/c-4-apartman-c2-2/',
#  'https://zelezna.sk/byty/c-3-apartman-c2-1/',
#  'https://zelezna.sk/byty/b-6-byt-b2-3/',
#  'https://zelezna.sk/byty/b-5-byt-b2-2/',
#  'https://zelezna.sk/byty/b-4-byt-b2-1/',
#  'https://zelezna.sk/byty/a-4-apartman-a2-2/',
#  'https://zelezna.sk/byty/a-3-apartman-a2-1/',
#  'https://zelezna.sk/byty/c-2-apartman-c1-2/',
#  'https://zelezna.sk/byty/c-1-apartman-c1-1/',
#  'https://zelezna.sk/byty/b-3-byt-b1-3/',
#  'https://zelezna.sk/byty/b-2-byt-b1-2/',
#  'https://zelezna.sk/byty/b-1-byt-b1-1/',
#  'https://zelezna.sk/byty/a-1-apartman-a1-1/',
#  'https://zelezna.sk/byty/a-2-apartman-a1-2/']

# %%
apartment_data = []

scrapingDate = datetime.today().strftime('%Y-%m-%d')
availableApartmentsCounter = 0

for link in links:

    dict = {

    "ApartmentName": None,
    "ApartmentAddress": "K Železnej studienke 7, 9, 11  ",
    "NumberOfRooms": None,
    "AppartmentFloor" : None,
    "ApartmentSize": None,
    "TotalAreaSize": None,
    "BalconySize" : None,
    "ReservationStatus": None,
    "SalesPrice": None,
    "ScrapingDate": scrapingDate,
    "ProjectName": 'Rezidencia K Železnej Studienke',
}

    sleep(2)

    res = requests.get(link, headers=headers)
    tree = lxml.html.fromstring(res.text)

    print(f"Getting link {link}")
    print(res)

    try:
        appName = tree.xpath('(//div[@class="wpb_wrapper"]/h2)[1]/text()')[0].strip()
        if not appName == '':
            dict["ApartmentName"] =  appName
    except IndexError:
        pass

    try:
        numberOfRooms = tree.xpath('//div[@class="nectar-fancy-ul"]//ul/li[1]/strong/following-sibling::text()')[0].strip().replace('–', '')
        if not numberOfRooms == '':
            dict["NumberOfRooms"] =  int(numberOfRooms)
    except IndexError:
        pass

    try:
        apartmentFloor =  tree.xpath('//div[@class="nectar-fancy-ul"]//ul/li[2]/strong/following-sibling::text()')[0].strip().replace('–', '')
        if not apartmentFloor == '':
            dict["AppartmentFloor"] =  apartmentFloor
    except IndexError:
        pass

    try:
        apartmentSize =  tree.xpath('//div[@class="nectar-fancy-ul"]//ul/li[3]/strong/following-sibling::text()')[0].strip().replace(',','.').replace('–', '')
        if not apartmentSize == '':
            dict["ApartmentSize"] =  float(apartmentSize)
        
    except IndexError:
        pass

    try:
        totalAreaSize =  tree.xpath('//div[@class="nectar-fancy-ul"]//ul/li[5]/strong/following-sibling::text()')[0].strip().replace(',','.').replace('–', '')
        if not totalAreaSize == '':
            dict["TotalAreaSize"] =  float(totalAreaSize)
    
    except IndexError:
        pass

    try:
        balconySize =  tree.xpath('//div[@class="nectar-fancy-ul"]//ul/li[4]/strong/following-sibling::text()')[0].strip().replace(',','.').replace('–', '')
        if not balconySize == '':
            dict["BalconySize"] =  float(balconySize)
    
    except IndexError:
        pass

    try:
        dict["ReservationStatus"] =  tree.xpath('(//div[@class="wpb_wrapper"])[4]/h3/span/text()')[0].strip().replace('–', '')
        if dict["ReservationStatus"] == 'Voľný':
            availableApartmentsCounter += 1
    except IndexError:
        pass

    try:
        salesPrice =  tree.xpath('(//div[@class="wpb_wrapper"])[5]/h3/span/text()')[0].strip().replace(' €', '').replace(',','.').replace(' ', '').replace('–', '')

        if not salesPrice == '':
            dict["SalesPrice"] =  float(salesPrice)
    
    except IndexError:
        pass
    
    apartment_data.append(dict)
# Out:
# Getting link https://zelezna.sk/byty/c-12-apartman-c5-1/
# <Response [200]>
# Getting link https://zelezna.sk/byty/a-9-apartman-a5-1/
# <Response [200]>
# Getting link https://zelezna.sk/byty/c-11-apartman-c4-3/
# <Response [200]>
# Getting link https://zelezna.sk/byty/c-10-apartman-c4-2/
# <Response [200]>
# Getting link https://zelezna.sk/byty/c-9-apartman-c4-1/
# <Response [200]>
# Getting link https://zelezna.sk/byty/b-12-byt-b4-3/
# <Response [200]>
# Getting link https://zelezna.sk/byty/b-11-byt-b4-2/
# <Response [200]>
# Getting link https://zelezna.sk/byty/b-10-byt-b4-1/
# <Response [200]>
# Getting link https://zelezna.sk/byty/a-8-apartman-a4-2/
# <Response [200]>
# Getting link https://zelezna.sk/byty/a-7-apartman-a4-1/
# <Response [200]>
# Getting link https://zelezna.sk/byty/c-8-apartman-c3-3/
# <Response [200]>
# Getting link https://zelezna.sk/byty/c-7-apartman-c3-2/
# <Response [200]>
# Getting link https://zelezna.sk/byty/c-6-apartman-c3-1/
# <Response [200]>
# Getting link https://zelezna.sk/byty/b-9-byt-b3-3/
# <Response [200]>
# Getting link https://zelezna.sk/byty/b-8-byt-b3-2/
# <Response [200]>
# Getting link https://zelezna.sk/byty/b-7-byt-b3-1/
# <Response [200]>
# Getting link https://zelezna.sk/byty/a-6-apartman-a3-2/
# <Response [200]>
# Getting link https://zelezna.sk/byty/a-5-apartman-a3-1/
# <Response [200]>
# Getting link https://zelezna.sk/byty/c-5-apartman-c2-3/
# <Response [200]>
# Getting link https://zelezna.sk/byty/c-4-apartman-c2-2/
# <Response [200]>
# Getting link https://zelezna.sk/byty/c-3-apartman-c2-1/
# <Response [200]>
# Getting link https://zelezna.sk/byty/b-6-byt-b2-3/
# <Response [200]>
# Getting link https://zelezna.sk/byty/b-5-byt-b2-2/
# <Response [200]>
# Getting link https://zelezna.sk/byty/b-4-byt-b2-1/
# <Response [200]>
# Getting link https://zelezna.sk/byty/a-4-apartman-a2-2/
# <Response [200]>
# Getting link https://zelezna.sk/byty/a-3-apartman-a2-1/
# <Response [200]>
# Getting link https://zelezna.sk/byty/c-2-apartman-c1-2/
# <Response [200]>
# Getting link https://zelezna.sk/byty/c-1-apartman-c1-1/
# <Response [200]>
# Getting link https://zelezna.sk/byty/b-3-byt-b1-3/
# <Response [200]>
# Getting link https://zelezna.sk/byty/b-2-byt-b1-2/
# <Response [200]>
# Getting link https://zelezna.sk/byty/b-1-byt-b1-1/
# <Response [200]>
# Getting link https://zelezna.sk/byty/a-1-apartman-a1-1/
# <Response [200]>
# Getting link https://zelezna.sk/byty/a-2-apartman-a1-2/
# <Response [200]>

# %%
apartment_data
# Out:
# [{'ApartmentName': 'C 12 Apartmán C5.1',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 4,
#   'AppartmentFloor': '5. NP',
#   'ApartmentSize': 196.73,
#   'TotalAreaSize': 397.41,
#   'BalconySize': 200.68,
#   'ReservationStatus': 'Voľný',
#   'SalesPrice': 1067082.0,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'A 9 Apartmán A5.1',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 4,
#   'AppartmentFloor': '5. NP',
#   'ApartmentSize': 133.88,
#   'TotalAreaSize': 334.78,
#   'BalconySize': 200.9,
#   'ReservationStatus': 'Voľný',
#   'SalesPrice': 803376.0,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'C 11 Apartmán C4.3',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 3,
#   'AppartmentFloor': '4. NP',
#   'ApartmentSize': 103.44,
#   'TotalAreaSize': 118.32,
#   'BalconySize': 14.88,
#   'ReservationStatus': 'Predaný',
#   'SalesPrice': None,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'C 10 Apartmán C4.2',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 2,
#   'AppartmentFloor': '4. NP',
#   'ApartmentSize': None,
#   'TotalAreaSize': 65.79,
#   'BalconySize': 17.19,
#   'ReservationStatus': 'Predaný',
#   'SalesPrice': None,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'C 9 Apartmán C4.1',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 3,
#   'AppartmentFloor': '4. NP',
#   'ApartmentSize': 90.03,
#   'TotalAreaSize': 97.96,
#   'BalconySize': 7.93,
#   'ReservationStatus': 'Rezervovaný',
#   'SalesPrice': 377454.0,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'B 12 Byt B4.3',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 2,
#   'AppartmentFloor': '4. NP',
#   'ApartmentSize': 56.56,
#   'TotalAreaSize': 71.85,
#   'BalconySize': 15.29,
#   'ReservationStatus': 'Predaný',
#   'SalesPrice': None,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'B 11 Byt B4.2',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 4,
#   'AppartmentFloor': '4. NP',
#   'ApartmentSize': 127.59,
#   'TotalAreaSize': 154.0,
#   'BalconySize': 26.31,
#   'ReservationStatus': 'Voľný',
#   'SalesPrice': 575110.8,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'B 10 Byt B4.1',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 2,
#   'AppartmentFloor': '4. NP',
#   'ApartmentSize': 56.05,
#   'TotalAreaSize': 70.44,
#   'BalconySize': 14.39,
#   'ReservationStatus': 'Predaný',
#   'SalesPrice': None,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'A 8 Apartmán A4.2',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 3,
#   'AppartmentFloor': '4. NP',
#   'ApartmentSize': 94.02,
#   'TotalAreaSize': 101.02,
#   'BalconySize': 7.0,
#   'ReservationStatus': 'Voľný',
#   'SalesPrice': 390799.2,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'A 7 Apartmán A4.1',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 3,
#   'AppartmentFloor': '4. NP',
#   'ApartmentSize': 102.47,
#   'TotalAreaSize': 122.26,
#   'BalconySize': 19.8,
#   'ReservationStatus': 'Rezervovaný',
#   'SalesPrice': 458013.6,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'C 8 Apartmán C3.3',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 3,
#   'AppartmentFloor': '3. NP',
#   'ApartmentSize': 103.44,
#   'TotalAreaSize': 118.32,
#   'BalconySize': 14.88,
#   'ReservationStatus': 'Voľný',
#   'SalesPrice': 448905.6,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'C 7 Apartmán C3.2',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 2,
#   'AppartmentFloor': '3. NP',
#   'ApartmentSize': 48.6,
#   'TotalAreaSize': 65.79,
#   'BalconySize': 17.19,
#   'ReservationStatus': 'Predaný',
#   'SalesPrice': None,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'C 6 Apartmán C3.1',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 3,
#   'AppartmentFloor': '3. NP',
#   'ApartmentSize': 90.03,
#   'TotalAreaSize': 97.96,
#   'BalconySize': 7.93,
#   'ReservationStatus': 'Predaný',
#   'SalesPrice': None,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'B 9 Byt B3.3',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 2,
#   'AppartmentFloor': '3. NP',
#   'ApartmentSize': 56.01,
#   'TotalAreaSize': 71.3,
#   'BalconySize': 15.29,
#   'ReservationStatus': 'Predaný',
#   'SalesPrice': 272556.0,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'B 8 Byt B3.2',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 4,
#   'AppartmentFloor': '3. NP',
#   'ApartmentSize': 127.69,
#   'TotalAreaSize': 154.0,
#   'BalconySize': 26.31,
#   'ReservationStatus': 'Voľný',
#   'SalesPrice': 577803.6,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'B 7 Byt B3.1',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 2,
#   'AppartmentFloor': '3. NP',
#   'ApartmentSize': 56.05,
#   'TotalAreaSize': 70.44,
#   'BalconySize': 14.39,
#   'ReservationStatus': 'Voľný',
#   'SalesPrice': 270127.2,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'A 6 Apartmán A3.2',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 3,
#   'AppartmentFloor': '3. NP',
#   'ApartmentSize': 94.02,
#   'TotalAreaSize': 101.02,
#   'BalconySize': 7.0,
#   'ReservationStatus': 'Voľný',
#   'SalesPrice': 390799.2,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'Apartmán A3.1',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 3,
#   'AppartmentFloor': '3. NP',
#   'ApartmentSize': 102.46,
#   'TotalAreaSize': 122.26,
#   'BalconySize': 19.8,
#   'ReservationStatus': 'Voľný',
#   'SalesPrice': 458013.6,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'C 5 Apartmán C2.3',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 3,
#   'AppartmentFloor': '2. NP',
#   'ApartmentSize': 103.49,
#   'TotalAreaSize': 118.37,
#   'BalconySize': 14.88,
#   'ReservationStatus': 'Voľný',
#   'SalesPrice': 449103.6,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'C 4 Apartmán C2.2',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 1,
#   'AppartmentFloor': '2. NP',
#   'ApartmentSize': 32.93,
#   'TotalAreaSize': 42.65,
#   'BalconySize': 9.72,
#   'ReservationStatus': 'Predaný',
#   'SalesPrice': None,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'C 3 Apartmán C2.1',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 3,
#   'AppartmentFloor': '2. NP',
#   'ApartmentSize': 106.39,
#   'TotalAreaSize': 121.78,
#   'BalconySize': 15.39,
#   'ReservationStatus': 'Voľný',
#   'SalesPrice': 461934.0,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'Rozmery izieb (m2)',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 2,
#   'AppartmentFloor': '2. NP',
#   'ApartmentSize': 56.01,
#   'TotalAreaSize': 71.3,
#   'BalconySize': 15.29,
#   'ReservationStatus': 'Rezervovaný',
#   'SalesPrice': 272556.0,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'B 5 Byt B2.2',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 4,
#   'AppartmentFloor': '2. NP',
#   'ApartmentSize': 125.94,
#   'TotalAreaSize': 154.68,
#   'BalconySize': 26.31,
#   'ReservationStatus': 'Predaný',
#   'SalesPrice': None,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'B 4 Byt B2.1',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 2,
#   'AppartmentFloor': '2. NP',
#   'ApartmentSize': 56.05,
#   'TotalAreaSize': 70.44,
#   'BalconySize': 14.39,
#   'ReservationStatus': 'Voľný',
#   'SalesPrice': 270127.2,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'A 4 Apartmán A2.2',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 3,
#   'AppartmentFloor': '2. NP',
#   'ApartmentSize': 94.02,
#   'TotalAreaSize': 101.02,
#   'BalconySize': 7.0,
#   'ReservationStatus': 'Predaný',
#   'SalesPrice': None,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'A 3 Apartmán A2.1',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 3,
#   'AppartmentFloor': '2. NP',
#   'ApartmentSize': 102.46,
#   'TotalAreaSize': 122.26,
#   'BalconySize': 19.8,
#   'ReservationStatus': 'Voľný',
#   'SalesPrice': 458013.6,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'C 2 Apartmán C1.2',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 3,
#   'AppartmentFloor': '1. NP',
#   'ApartmentSize': 103.06,
#   'TotalAreaSize': 125.61,
#   'BalconySize': 22.55,
#   'ReservationStatus': 'Predaný',
#   'SalesPrice': None,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'C 1 Apartmán C1.1',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 2,
#   'AppartmentFloor': '1. NP',
#   'ApartmentSize': 74.21,
#   'TotalAreaSize': 111.57,
#   'BalconySize': 37.36,
#   'ReservationStatus': 'Voľný',
#   'SalesPrice': 410373.6,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'B 3 Byt B1.3',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 2,
#   'AppartmentFloor': '1. NP',
#   'ApartmentSize': 56.56,
#   'TotalAreaSize': 80.99,
#   'BalconySize': 24.43,
#   'ReservationStatus': 'Voľný',
#   'SalesPrice': 301123.2,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'B 2 Byt B1.2',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 3,
#   'AppartmentFloor': '1. NP',
#   'ApartmentSize': 127.56,
#   'TotalAreaSize': 144.03,
#   'BalconySize': 16.47,
#   'ReservationStatus': 'Voľný',
#   'SalesPrice': 548618.4,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'B 1 Byt B1.1',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 1,
#   'AppartmentFloor': '1. NP',
#   'ApartmentSize': 39.13,
#   'TotalAreaSize': 39.13,
#   'BalconySize': None,
#   'ReservationStatus': 'Predaný',
#   'SalesPrice': 164346.0,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'A 1 Apartmán A1.1',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 2,
#   'AppartmentFloor': '1. NP',
#   'ApartmentSize': 91.07,
#   'TotalAreaSize': 114.16,
#   'BalconySize': 23.09,
#   'ReservationStatus': 'Voľný',
#   'SalesPrice': 438064.8,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'A 2 Apartmán A1.2',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 3,
#   'AppartmentFloor': '1. NP',
#   'ApartmentSize': None,
#   'TotalAreaSize': 108.72,
#   'BalconySize': 11.78,
#   'ReservationStatus': 'Voľný',
#   'SalesPrice': 414981.6,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'}]

# %%
def findApartmentInDB(apartment):
    url = 'http://127.0.0.1:8000/apartments'
    db_apartments = requests.get(url).json()
    for db_apartment in db_apartments:
        if db_apartment['ApartmentName'] == apartment['ApartmentName']:
            return db_apartment
    return None

def getLastApartmentInDB():
    url = 'http://127.0.0.1:8000/apartment/last'
    db_apartment = requests.get(url).json()
    return db_apartment

def findTodaysStatus(apartment):
    apartment_id = apartment["ApartmentID"]
    today = '2021-12-05'#datetime.today().strftime('%Y-%m-%d')
    url = f'http://127.0.0.1:8000/status/{apartment_id}/{today}'
    response = requests.get(url)
    if(response.status_code == 200):
        db_status = response.json()
        return db_status
    return None

def findProjectID(project_name):
    url = 'http://127.0.0.1:8000/projects'
    db_projects = requests.get(url).json()
    for db_project in db_projects:
        if db_project['ProjectName'] == project_name:
            return db_project['ProjectID']
    return -1

def getLastProjectInDB():
    url = 'http://127.0.0.1:8000/project/last'
    db_project = requests.get(url).json()
    return db_project

def findProjectInDBByName(project_name):
    url = 'http://127.0.0.1:8000/projects'
    db_projects = requests.get(url).json()
    for db_project in db_projects:
        if db_project['ProjectName'] == project_name:
            print(db_project)
            return db_project
    return None

def findTodaysAvailability(project):
    project_id = project["ProjectID"]
    today = datetime.today().strftime('%Y-%m-%d')
    url = f'http://127.0.0.1:8000/availability/{project_id}/{today}'
    response = requests.get(url)
    if(response.status_code == 200):
        db_availabilities = response.json()
        return db_availability
    return None


postApartmentUrl = 'http://127.0.0.1:8000/apartments'
statusUrl = 'http://127.0.0.1:8000/status'
postProjectUrl = 'http://127.0.0.1:8000/projects'
availabilityUrl = 'http://127.0.0.1:8000/availability'

# %%
db_project = findProjectInDBByName('Rezidencia K Železnej Studienke') 
if db_project != None: #if the project is already in the db
    db_projectAvailability = findTodaysAvailability(db_project)
    if db_projectAvailability != None: #if there is a availability for today in db - update its values
        updated_availability={
            'Project': db_project['ProjectID'],
            'ProjectAvailableApartments': availableApartmentsCounter,
            'ScrapingDate': scrapingDate          
        }
        response = requests.put(availabilityUrl, json = updated_availability)
        if(response.status_code == 200):
            print(f"Successfully updated availability for project: Rezidencia K Železnej Studienke")
        else:
            print(f"Failed to update availability for project: Rezidencia K Železnej Studienke")
    else: #if there is no availability in the db for today
        availability={
            'Project': db_project['ProjectID'],
            'ProjectAvailableApartments': availableApartmentsCounter,
            'ScrapingDate': scrapingDate     
        }
        response = requests.post(availabilityUrl, json = availability)
        if(response.status_code == 200):
            print(f"Successfully input todays availability for project: Rezidencia K Železnej Studienke")
        else:
            print(f"Failed to input todays availability for project: Rezidencia K Železnej Studienke")
else:
    projectData = {
        "ProjectName": 'Rezidencia K Železnej Studienke',
        "ProjectAddress": 'Bratislava I | K Železnej Studienke 7, 9, 11, 82, 81104 Bratislava',
        "ProjectTotalApartments": 33,
        "ScrapingDate": scrapingDate
    }
    response = requests.post(postProjectUrl, json = projectData)
    if(response.status_code == 200):
        last_project = getLastProjectInDB()
        availability={
            'Project': last_project['ProjectID'],
            'ProjectAvailableApartments': availableApartmentsCounter,
            'ScrapingDate': scrapingDate
        }
        response = requests.post(availabilityUrl, json = availability)
        if(response.status_code == 200):
            print(f"Successfully input project: Rezidencia K Železnej Studienke, and accompanying availability")
        else:
            print(f"Successfully input project: Rezidencia K Železnej Studienke, but NOT the availability")
    else:
        print(f"Failed to imput project: Rezidencia K Železnej Studienke")
# Out:
# Successfully input project: Rezidencia K Železnej Studienke, and accompanying availability

# %%
for apartment in apartment_data:
    db_apartment = findApartmentInDB(apartment) 
    if db_apartment != None: #if the apartment is alreadI y in the db
        db_apartmentStatus = findTodaysStatus(db_apartment)
        if db_apartmentStatus != None: #if there is a status for today in db - update its values
            updated_status={
                'Apartment': db_apartment['ApartmentID'],
                'ReservationStatus': apartment['ReservationStatus'],
                'SalesPrice': apartment['SalesPrice'],
                'ScrapingDate': apartment['ScrapingDate'],           
            }
            response = requests.put(statusUrl, json = updated_status)
            if(response.status_code == 200):
                print(f"Successfully updated status for apartment: {db_apartment['ApartmentName']}")
            else:
                print(f"Failed to update status for apartment: {apartment['ApartmentName']}")
        else: #if there is no status in the db for today
            status={
                'Apartment': db_apartment['ApartmentID'],
                'ReservationStatus': apartment['ReservationStatus'],
                'SalesPrice': apartment['SalesPrice'],
                'ScrapingDate': apartment['ScrapingDate'],           
            }
            response = requests.post(statusUrl, json = status)
            if(response.status_code == 200):
                print(f"Successfully input todays status for apartment: {db_apartment['ApartmentName']}")
            else:
                print(f"Failed to input todays status for apartment: {apartment['ApartmentName']}")
    else: #if the apartment is not yet in the db
        apartmentData = {
            'ApartmentName': apartment['ApartmentName'],
            'ApartmentAddress': apartment['ApartmentAddress'],
            'NumberOfRooms': apartment['NumberOfRooms'],
            'AppartmentFloor': apartment['AppartmentFloor'],
            'ApartmentSize': apartment['ApartmentSize'],
            'TotalAreaSize': apartment['TotalAreaSize'],
            'BalconySize': apartment['BalconySize'],
            'ScrapingDate': apartment['ScrapingDate'],
            'Project': findProjectID(apartment['ProjectName'])
        }
        response = requests.post(postApartmentUrl, json = apartmentData)
        if(response.status_code == 200):
            last_apartment = getLastApartmentInDB()
            status={
                'Apartment': last_apartment['ApartmentID'],
                'ReservationStatus': apartment['ReservationStatus'],
                'SalesPrice': apartment['SalesPrice'],
                'ScrapingDate': apartment['ScrapingDate']
            }
            response = requests.post(statusUrl, json = status)
            if(response.status_code == 200):
                print(f"Successfully input apartment: {apartment['ApartmentName']}, and accompanying status")
            else:
                print(f"Successfully input apartment: {apartment['ApartmentName']}, but NOT the status")
        else:
            print(f"Failed to imput apartment: {apartment['ApartmentName']}")
# Out:
# Successfully input apartment: C 12 Apartmán C5.1, and accompanying status
# Successfully input apartment: A 9 Apartmán A5.1, and accompanying status
# Successfully input apartment: C 11 Apartmán C4.3, and accompanying status
# Successfully input apartment: C 10 Apartmán C4.2, and accompanying status
# Successfully input apartment: C 9 Apartmán C4.1, and accompanying status
# Successfully input apartment: B 12 Byt B4.3, and accompanying status
# Successfully input apartment: B 11 Byt B4.2, and accompanying status
# Successfully input apartment: B 10 Byt B4.1, and accompanying status
# Successfully input apartment: A 8 Apartmán A4.2, and accompanying status
# Successfully input apartment: A 7 Apartmán A4.1, and accompanying status
# Successfully input apartment: C 8 Apartmán C3.3, and accompanying status
# Successfully input apartment: C 7 Apartmán C3.2, and accompanying status
# Successfully input apartment: C 6 Apartmán C3.1, and accompanying status
# Successfully input apartment: B 9 Byt B3.3, and accompanying status
# Successfully input apartment: B 8 Byt B3.2, and accompanying status
# Successfully input apartment: B 7 Byt B3.1, and accompanying status
# Successfully input apartment: A 6 Apartmán A3.2, and accompanying status
# Successfully input apartment: Apartmán A3.1, and accompanying status
# Successfully input apartment: C 5 Apartmán C2.3, and accompanying status
# Successfully input apartment: C 4 Apartmán C2.2, and accompanying status
# Successfully input apartment: C 3 Apartmán C2.1, and accompanying status
# Successfully input apartment: Rozmery izieb (m2), and accompanying status
# Successfully input apartment: B 5 Byt B2.2, and accompanying status
# Successfully input apartment: B 4 Byt B2.1, and accompanying status
# Successfully input apartment: A 4 Apartmán A2.2, and accompanying status
# Successfully input apartment: A 3 Apartmán A2.1, and accompanying status
# Successfully input apartment: C 2 Apartmán C1.2, and accompanying status
# Successfully input apartment: C 1 Apartmán C1.1, and accompanying status
# Successfully input apartment: B 3 Byt B1.3, and accompanying status
# Successfully input apartment: B 2 Byt B1.2, and accompanying status
# Successfully input apartment: B 1 Byt B1.1, and accompanying status
# Successfully input apartment: A 1 Apartmán A1.1, and accompanying status
# Successfully input apartment: A 2 Apartmán A1.2, and accompanying status

# %%
apartment_data
# Out:
# [{'ApartmentName': 'C 12 Apartmán C5.1',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 4,
#   'AppartmentFloor': '5. NP',
#   'ApartmentSize': 196.73,
#   'TotalAreaSize': 397.41,
#   'BalconySize': 200.68,
#   'ReservationStatus': 'Voľný',
#   'SalesPrice': 1067082.0,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'A 9 Apartmán A5.1',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 4,
#   'AppartmentFloor': '5. NP',
#   'ApartmentSize': 133.88,
#   'TotalAreaSize': 334.78,
#   'BalconySize': 200.9,
#   'ReservationStatus': 'Voľný',
#   'SalesPrice': 803376.0,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'C 11 Apartmán C4.3',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 3,
#   'AppartmentFloor': '4. NP',
#   'ApartmentSize': 103.44,
#   'TotalAreaSize': 118.32,
#   'BalconySize': 14.88,
#   'ReservationStatus': 'Predaný',
#   'SalesPrice': None,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'C 10 Apartmán C4.2',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 2,
#   'AppartmentFloor': '4. NP',
#   'ApartmentSize': None,
#   'TotalAreaSize': 65.79,
#   'BalconySize': 17.19,
#   'ReservationStatus': 'Predaný',
#   'SalesPrice': None,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'C 9 Apartmán C4.1',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 3,
#   'AppartmentFloor': '4. NP',
#   'ApartmentSize': 90.03,
#   'TotalAreaSize': 97.96,
#   'BalconySize': 7.93,
#   'ReservationStatus': 'Rezervovaný',
#   'SalesPrice': 377454.0,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'B 12 Byt B4.3',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 2,
#   'AppartmentFloor': '4. NP',
#   'ApartmentSize': 56.56,
#   'TotalAreaSize': 71.85,
#   'BalconySize': 15.29,
#   'ReservationStatus': 'Predaný',
#   'SalesPrice': None,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'B 11 Byt B4.2',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 4,
#   'AppartmentFloor': '4. NP',
#   'ApartmentSize': 127.59,
#   'TotalAreaSize': 154.0,
#   'BalconySize': 26.31,
#   'ReservationStatus': 'Voľný',
#   'SalesPrice': 575110.8,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'B 10 Byt B4.1',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 2,
#   'AppartmentFloor': '4. NP',
#   'ApartmentSize': 56.05,
#   'TotalAreaSize': 70.44,
#   'BalconySize': 14.39,
#   'ReservationStatus': 'Predaný',
#   'SalesPrice': None,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'A 8 Apartmán A4.2',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 3,
#   'AppartmentFloor': '4. NP',
#   'ApartmentSize': 94.02,
#   'TotalAreaSize': 101.02,
#   'BalconySize': 7.0,
#   'ReservationStatus': 'Voľný',
#   'SalesPrice': 390799.2,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'A 7 Apartmán A4.1',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 3,
#   'AppartmentFloor': '4. NP',
#   'ApartmentSize': 102.47,
#   'TotalAreaSize': 122.26,
#   'BalconySize': 19.8,
#   'ReservationStatus': 'Rezervovaný',
#   'SalesPrice': 458013.6,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'C 8 Apartmán C3.3',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 3,
#   'AppartmentFloor': '3. NP',
#   'ApartmentSize': 103.44,
#   'TotalAreaSize': 118.32,
#   'BalconySize': 14.88,
#   'ReservationStatus': 'Voľný',
#   'SalesPrice': 448905.6,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'C 7 Apartmán C3.2',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 2,
#   'AppartmentFloor': '3. NP',
#   'ApartmentSize': 48.6,
#   'TotalAreaSize': 65.79,
#   'BalconySize': 17.19,
#   'ReservationStatus': 'Predaný',
#   'SalesPrice': None,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'C 6 Apartmán C3.1',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 3,
#   'AppartmentFloor': '3. NP',
#   'ApartmentSize': 90.03,
#   'TotalAreaSize': 97.96,
#   'BalconySize': 7.93,
#   'ReservationStatus': 'Predaný',
#   'SalesPrice': None,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'B 9 Byt B3.3',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 2,
#   'AppartmentFloor': '3. NP',
#   'ApartmentSize': 56.01,
#   'TotalAreaSize': 71.3,
#   'BalconySize': 15.29,
#   'ReservationStatus': 'Predaný',
#   'SalesPrice': 272556.0,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'B 8 Byt B3.2',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 4,
#   'AppartmentFloor': '3. NP',
#   'ApartmentSize': 127.69,
#   'TotalAreaSize': 154.0,
#   'BalconySize': 26.31,
#   'ReservationStatus': 'Voľný',
#   'SalesPrice': 577803.6,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'B 7 Byt B3.1',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 2,
#   'AppartmentFloor': '3. NP',
#   'ApartmentSize': 56.05,
#   'TotalAreaSize': 70.44,
#   'BalconySize': 14.39,
#   'ReservationStatus': 'Voľný',
#   'SalesPrice': 270127.2,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'A 6 Apartmán A3.2',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 3,
#   'AppartmentFloor': '3. NP',
#   'ApartmentSize': 94.02,
#   'TotalAreaSize': 101.02,
#   'BalconySize': 7.0,
#   'ReservationStatus': 'Voľný',
#   'SalesPrice': 390799.2,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'Apartmán A3.1',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 3,
#   'AppartmentFloor': '3. NP',
#   'ApartmentSize': 102.46,
#   'TotalAreaSize': 122.26,
#   'BalconySize': 19.8,
#   'ReservationStatus': 'Voľný',
#   'SalesPrice': 458013.6,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'C 5 Apartmán C2.3',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 3,
#   'AppartmentFloor': '2. NP',
#   'ApartmentSize': 103.49,
#   'TotalAreaSize': 118.37,
#   'BalconySize': 14.88,
#   'ReservationStatus': 'Voľný',
#   'SalesPrice': 449103.6,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'C 4 Apartmán C2.2',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 1,
#   'AppartmentFloor': '2. NP',
#   'ApartmentSize': 32.93,
#   'TotalAreaSize': 42.65,
#   'BalconySize': 9.72,
#   'ReservationStatus': 'Predaný',
#   'SalesPrice': None,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'C 3 Apartmán C2.1',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 3,
#   'AppartmentFloor': '2. NP',
#   'ApartmentSize': 106.39,
#   'TotalAreaSize': 121.78,
#   'BalconySize': 15.39,
#   'ReservationStatus': 'Voľný',
#   'SalesPrice': 461934.0,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'Rozmery izieb (m2)',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 2,
#   'AppartmentFloor': '2. NP',
#   'ApartmentSize': 56.01,
#   'TotalAreaSize': 71.3,
#   'BalconySize': 15.29,
#   'ReservationStatus': 'Rezervovaný',
#   'SalesPrice': 272556.0,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'B 5 Byt B2.2',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 4,
#   'AppartmentFloor': '2. NP',
#   'ApartmentSize': 125.94,
#   'TotalAreaSize': 154.68,
#   'BalconySize': 26.31,
#   'ReservationStatus': 'Predaný',
#   'SalesPrice': None,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'B 4 Byt B2.1',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 2,
#   'AppartmentFloor': '2. NP',
#   'ApartmentSize': 56.05,
#   'TotalAreaSize': 70.44,
#   'BalconySize': 14.39,
#   'ReservationStatus': 'Voľný',
#   'SalesPrice': 270127.2,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'A 4 Apartmán A2.2',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 3,
#   'AppartmentFloor': '2. NP',
#   'ApartmentSize': 94.02,
#   'TotalAreaSize': 101.02,
#   'BalconySize': 7.0,
#   'ReservationStatus': 'Predaný',
#   'SalesPrice': None,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'A 3 Apartmán A2.1',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 3,
#   'AppartmentFloor': '2. NP',
#   'ApartmentSize': 102.46,
#   'TotalAreaSize': 122.26,
#   'BalconySize': 19.8,
#   'ReservationStatus': 'Voľný',
#   'SalesPrice': 458013.6,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'C 2 Apartmán C1.2',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 3,
#   'AppartmentFloor': '1. NP',
#   'ApartmentSize': 103.06,
#   'TotalAreaSize': 125.61,
#   'BalconySize': 22.55,
#   'ReservationStatus': 'Predaný',
#   'SalesPrice': None,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'C 1 Apartmán C1.1',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 2,
#   'AppartmentFloor': '1. NP',
#   'ApartmentSize': 74.21,
#   'TotalAreaSize': 111.57,
#   'BalconySize': 37.36,
#   'ReservationStatus': 'Voľný',
#   'SalesPrice': 410373.6,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'B 3 Byt B1.3',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 2,
#   'AppartmentFloor': '1. NP',
#   'ApartmentSize': 56.56,
#   'TotalAreaSize': 80.99,
#   'BalconySize': 24.43,
#   'ReservationStatus': 'Voľný',
#   'SalesPrice': 301123.2,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'B 2 Byt B1.2',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 3,
#   'AppartmentFloor': '1. NP',
#   'ApartmentSize': 127.56,
#   'TotalAreaSize': 144.03,
#   'BalconySize': 16.47,
#   'ReservationStatus': 'Voľný',
#   'SalesPrice': 548618.4,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'B 1 Byt B1.1',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 1,
#   'AppartmentFloor': '1. NP',
#   'ApartmentSize': 39.13,
#   'TotalAreaSize': 39.13,
#   'BalconySize': None,
#   'ReservationStatus': 'Predaný',
#   'SalesPrice': 164346.0,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'A 1 Apartmán A1.1',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 2,
#   'AppartmentFloor': '1. NP',
#   'ApartmentSize': 91.07,
#   'TotalAreaSize': 114.16,
#   'BalconySize': 23.09,
#   'ReservationStatus': 'Voľný',
#   'SalesPrice': 438064.8,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'},
#  {'ApartmentName': 'A 2 Apartmán A1.2',
#   'ApartmentAddress': 'K Železnej studienke 7, 9, 11  ',
#   'NumberOfRooms': 3,
#   'AppartmentFloor': '1. NP',
#   'ApartmentSize': None,
#   'TotalAreaSize': 108.72,
#   'BalconySize': 11.78,
#   'ReservationStatus': 'Voľný',
#   'SalesPrice': 414981.6,
#   'ScrapingDate': '2021-12-06',
#   'ProjectName': 'Rezidencia K Železnej Studienke'}]
