# %%
pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\pako\desktop\realestate-api-final\env\lib\site-packages (2.26.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\pako\desktop\realestate-api-final\env\lib\site-packages (from requests) (2.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pako\desktop\realestate-api-final\env\lib\site-packages (from requests) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pako\desktop\realestate-api-final\env\lib\site-packages (from requests) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\pako\desktop\realestate-api-final\env\lib\site-packages (from requests) (1.26.7)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\Users\Pako\Desktop\realestate-api-final\env\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-1.3.4-cp39-cp39-win_amd64.whl (10.2 MB)
# Collecting numpy>=1.17.3
#   Downloading numpy-1.21.4-cp39-cp39-win_amd64.whl (14.0 MB)
# Collecting pytz>=2017.3
#   Using cached pytz-2021.3-py2.py3-none-any.whl (503 kB)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\pako\desktop\realestate-api-final\env\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\pako\desktop\realestate-api-final\env\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Installing collected packages: pytz, numpy, pandas
# Successfully installed numpy-1.21.4 pandas-1.3.4 pytz-2021.3
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\Users\Pako\Desktop\realestate-api-final\env\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import requests
import json
import pandas as pd
from datetime import datetime
import json

# %%
payload = {
    "PageSize": 4,
    "StartPage": 0,
    "QueryString": "*",
    "UILanguage": "sk",
    "PageId": 21747,
    "BlockId": 0,
    "SiteId": "yit.sk",
    "Attrs": [
        "inap"
    ],
    "Fields": None,
    "CacheMaxAge": 0,
    "Filter": {
        "Field": "Locale",
        "Value": "sk",
        "Operator": "Equals",
        "AndConditions": [
            {
                "Field": "ProjectPublish",
                "Value": True,
                "Operator": "Equals",
                "AndConditions": [],
                "OrConditions": []
            },
            {
                "Field": "IsAvailable",
                "Value": True,
                "Operator": "Equals",
                "AndConditions": [],
                "OrConditions": []
            },
            {
                "Field": "ProductItemForSale",
                "Value": True,
                "Operator": "Equals",
                "AndConditions": [],
                "OrConditions": []
            },
            {
                "Field": "AreaIds",
                "Value": "cityv62u-q27j-49ue-j59q86mus34t",
                "Operator": "Any",
                "AndConditions": [],
                "OrConditions": []
            },
            {
                "Field": "BuildingTypeKey",
                "Value": [
                    "BlockOfFlats",
                    "SemiDetachedHouse",
                    "DetachedHouse",
                    ""
                ],
                "Operator": "In",
                "AndConditions": [],
                "OrConditions": []
            }
        ],
        "OrConditions": []
    },
    "Facet": [],
    "Order": [
        {
            "Field": "ReservationStatusIndex"
        },
        {
            "Field": "CrmId"
        }
    ]
}

headers = {
'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.71 Safari/537.36',
'content-type': 'application/json; charset=utf-8',
'cookie': "TiPMix=23.5764657257015; x-ms-routing-name=self; ARRAffinity=9e6938bdd5273ac834b9c96b3a02aa5822bd44d7825a58ea9ec27f776457eeff; ARRAffinitySameSite=9e6938bdd5273ac834b9c96b3a02aa5822bd44d7825a58ea9ec27f776457eeff; ASP.NET_SessionId=d0ijxpchepzanwvjg5hi1qhp; EPi_NumberOfVisits=1,2021-12-02T22:39:23; YIT-SessionId=2021120222392360.d0ij1qhp; .EPiForm_BID=a2e30ef7-26b7-48a7-a874-d24ac00cf488; .EPiForm_VisitorIdentifier=a2e30ef7-26b7-48a7-a874-d24ac00cf488:; CookieConsent={stamp:'3gDDKMuxwN/W6C3JGGrP9gR3EIHola272oSJhE/eKTp9lgucAilPWA==',necessary:true,preferences:true,statistics:true,marketing:true,ver:2,utc:1638484769533,iab2:'CPQnO9QPQnO9QCGABBENBtCsAP_AAH_AAAAAIOtf_X__bX9j-_59f_t0eY1P9_r_v-Qzjhfdt-8F2L_W_L0X42E7NF36pq4KuR4Eu3LBIQNlHMHUTUmwaokVrzHsak2MryNKJ7LEmnMZO2dYGHtPn91TuZKY7_78__fz3z-v_t_-39T37-3_3__5_X---_e_V399zLv9____39nN___9v-CDYBJhqXkAXYljgybRpVCiBGFYSHQCgAooBhaJrABgcFOysAj1BCwAQmoCMCIEGIKMGAQACAQBIREBIAWCARAEQCAAEAKkBCAAiYBBYAWBgEAAoBoWIEUAQgSEGRwVHKYEBEi0UEtlYAlF3saYQhllgBQKP6KjARKEECwMhIWDmOAJAS4WAAAA.YAAAAAAAAAAA',gacm:'1~...',region:'fr'}; giosg_gid_4106=4wlrozdvpkaphfvqfqaafo32gokfhqar5sds4ascvqjaagam; giosg_chat_id_4106=aqj6iuzvgjde6q5jlmaaoz6pf24bwzugofytlyzw6bt4asim; giosg_gsessid_4106=bb7a679c-53c0-11ec-872e-0242ac120018; _yit.search=1; YIT-SearchLeads-19190={}; _yit.visited=1; YIT-lvi=['a:cityv62u-q27j-49ue-j59q86mus34t']; YIT-SearchTabs-19190={'main':['apartments','partments-list'],'products':['apartments','apartments-list']}"
}

# %%
url = 'https://www.yit.sk/api/v1/productsearch/apartments'
r = requests.post(url, data=json.dumps(payload), headers=headers)
print(r.status_code)
# Out:
# 200

# %%
data = r.json()
total_pages = data['TotalHits']
total_pages
# Out:
# 167

# %%
payload['PageSize'] = total_pages

# %%
url = 'https://www.yit.sk/api/v1/productsearch/apartments'
r = requests.post(url, data=json.dumps(payload), headers=headers)
print(r.status_code)
# Out:
# 200

# %%
data = r.json()['Hits']
len(data)
data
# Out:
# [{'Id': '1-JGQHVD',
#   'Type': None,
#   'Score': 0.0,
#   'Fields': {'_Url': '/predaj-bytov/bratislava/ruzinov/nuppu/nuppu-orkidea/1-jgqhvd',
#    'ApartmentNumber': 'F 324',
#    'ApartmentB2BNumber': None,
#    'ReservationStatus': 'Voľný',
#    'ReservationStatusKey': 'Free',
#    'BuildingType': 'Bytový dom',
#    'BuildingTypeKey': 'BlockOfFlats',
#    'ApartmentType': 'Byt',
#    'AreaId': None,
#    'CrmId': '1-JGQHVD',
#    'MarketingHeadline': None,
#    'MarketingDescription': 'Byt slúži ako vzorový. V cene je zahrnuté kompletné vybavenie bytu a pivničná kobka. K bytu je potrebné zakúpiť parkovacie státie v garáži bytového domu.',
#    'AdditionalInformation': None,
#    'FloorNumber': '2',
#    'FloorNumberCorrectedFrom': 2,
#    'FloorNumberCorrectedTo': None,
#    'MarketingTag': None,
#    'MarketingTagKey': None,
#    'NumberOfRooms': '3',
#    'NumberOfRuComRooms': None,
#    'FloorsInApartment': None,
#    'ApartmentSize': 71.6,
#    'ProductItemSizeFrom': None,
#    'ProductItemSizeTo': None,
#    'OtherAreaSize': 0.0,
#    'TotalAreaSize': 75.53,
#    'ApartmentAddress': 'Hraničná 28 A, B, C F 324',
#    'FinishingType': None,
#    'SalesPrice': 304392.444,
#    'DebtShare': 50732.074,
#    'NonDebtPrice': 253660.37,
#    'SalesPricePerSquare': 4248.91742,
#    'NonDebtPricePerSquare': 0.0,
#    'PlotShareRedemptionPrice': 0.0,
#    'DecorationPackagePrice': 0.0,
#    'LeisureHomeTotalPrice': 0.0,
#    'PrivateHomePricing': 0.0,
#    'MaintenanceFee': 0.0,
#    'FinancingFeeInterestOnly': 0.0,
#    'TotalCharges1': 0.0,
#    'FinancingFeeTotal': 0.0,
#    'TotalCharges2': 0.0,
#    'PlotShareFee': 0.0,
#    'WaterFee': None,
#    'OtherFees': 0.0,
#    'DiscountPercentageLoan': 0.0,
#    'LoanPrice': 0.0,
#    'PricePerSqMLoan': 0.0,
#    'PriceWhenFullPayment': 0.0,
#    'DiscountWhenFullPayment': 0.0,
#    'PricePerSqMFullPayment': 0.0,
#    'PaymentOptions': None,
#    'PaymentOptionsKey': None,
#    'CrmDataApproved': True,
#    'SeoUrl': None,
#    'NumberOfRoomsFrom': 3,
#    'NumberOfRoomsTo': 3,
#    'KitchenSize': 0.0,
#    'KitchenType': None,
#    'Sauna': None,
#    'SaunaKey': None,
#    'Balcony': 'Áno',
#    'BalconyKey': 'True',
#    'BalconySize': 3.89,
#    'Terrace': None,
#    'TerraceKey': None,
#    'FirePlace': None,
#    'FirePlaceKey': None,
#    'TerraceSize': 0.0,
#    'BathroomType': None,
#    'WindowsOrientation': 'JV/SZ',
#    'ProductItemNonDebtAndPlotShareRedemptionPrice': None,
#    'ProductItemNonDebtAndAlterationOrDecorationPrice': None,
#    'ProductItemNonDebtAndPlotShareRedemptionPriceAndAltOrDecPrice': None,
#    'ProductItemForRent': False,
#    'ProductItemForSale': True,
#    'ProductItemRentDeposit': None,
#    'ProductItemMonthlyRent': None,
#    'ProductItemRentalStatusKey': None,
#    'ProductItemRentalStatus': None,
#    'TransformerMinNumberOfRooms': None,
#    'TransformerMaxNumberOfRooms': None,
#    'TransformerMinSize': None,
#    'TransformerMaxSize': None,
#    'TransformerMinPrice': None,
#    'TransformerMaxPrice': None,
#    'TransformerEndDate': None,
#    'OpenInfo1': None,
#    'OpenInfo2': None,
#    'OpenInfo3': '1',
#    'Release': None,
#    'ApartmentConditions': None,
#    'ApartmentConditionsKey': None,
#    'Pets': None,
#    'PetsKey': None,
#    'Landlord': None,
#    'LandlordKey': None,
#    'Fdr': None,
#    'ProjectId': '1-IIWWFF',
#    'ProjectCRMId': '1-IIWWFF',
#    'ProjectLongTitle': None,
#    'ProjectShortTitle': 'NUPPU - Orkidea',
#    'ProjectNameFromCrm': 'NUPPU - Orkidea',
#    'ProjectBusinessSegment': 'Bývanie',
#    'ProjectBusinessSegmentKey': 'Housing',
#    'ProjectAreaMarketingName': None,
#    'ProjectSiteCity': 'bratislava',
#    'ProjectSiteAddress': 'Hraničná 28, 28A, 28B',
#    'ProjectCountryCode': 'SK',
#    'ProjectCountryCodeKey': 'SK',
#    'ProjectSiteCountry': 'SK',
#    'ProjectSiteCountryKey': 'SK',
#    'ProjectDistrict': 'Bratislava II',
#    'ProjectMarketingName': 'NUPPU - Orkidea',
#    'ProjectMarketingHeadline': 'Orkidea',
#    'ProjectMarketingDescription': 'Bytové domy NUPPU majú podobnú kompozíciu, no predsa je každý originálny. Líšia sa farbou a fínskym názvom kvetu. Šiestou etapou je NUPPU Orkidea ktorá poskytne 98 bytových jednotiek na 8 nadzemných podlažiach.',
#    'ProjectCoordinatesLatitude': 48.143809,
#    'ProjectCoordinatesLongitude': 17.158374,
#    'ProjectNumberOfApartments': 98,
#    'ProjectNumberOfSellableParkingPlaces': None,
#    'ProjectNumberOfOtherParkingPlaces': None,
#    'ProjectAvailableParkingPlaces': 0,
#    'ProjectCommunications': None,
#    'ProjectHeatingSystem': None,
#    'ProjectLocationOfParkingLots': None,
#    'ProjectVentilationSystem': None,
#    'ProjectStatus': 'Building ready',
#    'ProjectStatusKey': 'BuildingReady',
#    'WebProjectStatus': 'Skolaudovaný ',
#    'WebProjectStatusKey': 'ReadyToMoveIn',
#    'WebProjectStatusCssClass': 's-ready',
#    'ProjectApartmentSurfaceTotal': 0.0,
#    'ProjectBusinessPremisesSurfaceTotal': 0.0,
#    'ProjectTranslationApproved': None,
#    'ProjectLocality': 'Bratislava',
#    'ProjectSalesOfficeKey': 'BRA',
#    'ProjectSalesOfficeKeyKey': None,
#    'ProjectFinishingType': None,
#    'ProjectCommonSpaces': None,
#    'ProjectEnergyClass': None,
#    'ProjectParkingPlaceAdditionalInfo': None,
#    'ProjectLeisureHomeBusinessPartner': None,
#    'ProjectSchemeForLoanPayment': None,
#    'ProjectPlotOwnership': None,
#    'ProjectPlotOwnershipCvl': None,
#    'ProjectPlotOwnershipCvlKey': None,
#    'ProjectPlotRent': 0.0,
#    'ProjectPlotSize': 0.0,
#    'ProjectFinancingMethod': None,
#    'ProjectB2BNewConstruction': None,
#    'ProjectB2BNewConstructionKey': None,
#    'ProjectB2BCompletionYear': None,
#    'ProjectB2BCompletionDate': None,
#    'ProjectB2BEstimatedCompletion': None,
#    'ProjectB2BAreaMin': None,
#    'ProjectB2BAreaMax': None,
#    'SubProjectId': '1-JGQHPD',
#    'SubProjectName': '6.apartments',
#    'SubProjectBuildingType': 'Bytový dom',
#    'SubProjectBuildingTypeKey': 'BlockOfFlats',
#    'SubProjectElevator': 'Áno',
#    'SubProjectElevatorKey': 'True',
#    'SubProjectNumberOfFloors': 8,
#    'SubProjectCrmDataApproved': True,
#    'SubProjectPimDataApproved': 'Záverečný',
#    'SubProjectPimDataApprovedKey': 'Final',
#    'SubProjectPriceCommentsField': None,
#    'SubProjectCrmId': '1-JGQHPD',
#    'SubProjectConceptFilter': None,
#    'SubProjectConceptFilterKey': None,
#    'SubProjectConceptFilterAndLabel': None,
#    'SubProjectConceptFilterAndLabelKey': None,
#    'SubProjectForRent': None,
#    'SubProjectForSale': None,
#    'Urls': None,
#    'CompletionDate': '2022-03-31T00:00:00Z',
#    'Address': 'Bratislava II | Hraničná 28, 28A, 28B, 82105 bratislava',
#    'CmsFloorNumberOfTotalFloors': '2/8',
#    'CmsB2BProductItemSize': '71.6',
#    'CmsTransformerNumberOfRooms': '3',
#    'CmsTransformerNumberOfRuComRooms': None,
#    'CmsTransformerTotalAreaSize': '75,53',
#    'CmsTransformerKitchenSize': '0',
#    'CmsTransformerLivingAreaSize': '71,6',
#    'CmsTransformerPriceWhenFullPayment': '0',
#    'ApartmentId': '1-JGQHVD',
#    '_Locality': 'Bratislava',
#    '_AvailabilityStatusText': 'Voľný',
#    '_AvailabilityStatusKey': 'Free',
#    '_AvailabilityStatusCssClass': 'free',
#    '_FloorPlanImageUrl': 'https://res.cloudinary.com/yit/image/upload/q_auto:eco,f_auto,fl_lossy,w_700,c_limit/v1593431813/295984.jpg',
#    '_FloorPlanLargeImageUrl': 'https://res.cloudinary.com/yit/image/upload/q_auto:eco,f_auto,fl_lossy,w_1920,c_limit/v1593431813/295984.jpg',
#    '_HasFloorPlan': True,
#    '_NextShowingText': None,
#    '_CampaignBadge': None,
#    '_ProjectBuildingTypes': 'Bytový dom',
#    '_Buttons': [],
#    '_Transformer': False,
#    '_Badges': [{'Title': 'Samostatné wc',
#      'Icon': 'https://res.cloudinary.com/yit/image/upload/q_auto:eco,f_auto,fl_lossy,w_150,c_limit/v1568879132/245353.jpg'},
#     {'Title': 'Veľká spálňa ',
#      'Icon': 'https://res.cloudinary.com/yit/image/upload/q_auto:eco,f_auto,fl_lossy,w_150,c_limit/v1568879117/245342.jpg'},
#     {'Title': 'Okná na 2 svetové strany',
#      'Icon': 'https://res.cloudinary.com/yit/image/upload/q_auto:eco,f_auto,fl_lossy,w_150,c_limit/v1568879150/245364.jpg'}],
#    '_LayoutType': None}},
#  {'Id': '1-JGQXDT',
#   'Type': None,
#   'Score': 0.0,
#   'Fields': {'_Url': '/predaj-bytov/bratislava/ruzinov/nuppu/nuppu-orkidea/1-jgqxdt',
#    'ApartmentNumber': 'F 175',
#    'ApartmentB2BNumber': None,
#    'ReservationStatus': 'Voľný',
#    'ReservationStatusKey': 'Free',
#    'BuildingType': 'Bytový dom',
#    'BuildingTypeKey': 'BlockOfFlats',
#    'ApartmentType': 'Byt',
#    'AreaId': None,
#    'CrmId': '1-JGQXDT',
#    'MarketingHeadline': None,
#    'MarketingDescription': 'V cene je zahrnutá pivničná kobka a bytový štandard (podlaha, interiérové a vstupné dvere, dlažba, obklady, sanita). K bytu je potrebné zakúpiť parkovacie státie v garáži bytového domu.',
#    'AdditionalInformation': None,
#    'FloorNumber': '7',
#    'FloorNumberCorrectedFrom': 7,
#    'FloorNumberCorrectedTo': None,
#    'MarketingTag': None,
#    'MarketingTagKey': None,
#    'NumberOfRooms': '1',
#    'NumberOfRuComRooms': None,
#    'FloorsInApartment': None,
#    'ApartmentSize': 40.4,
#    'ProductItemSizeFrom': None,
#    'ProductItemSizeTo': None,
#    'OtherAreaSize': 0.0,
#    'TotalAreaSize': 46.77,
#    'ApartmentAddress': 'Hraničná 28 A, B, C F 175',
#    'FinishingType': None,
#    'SalesPrice': 174990.6,
#    'DebtShare': 29165.1,
#    'NonDebtPrice': 145825.5,
#    'SalesPricePerSquare': 4329.30727,
#    'NonDebtPricePerSquare': 0.0,
#    'PlotShareRedemptionPrice': 0.0,
#    'DecorationPackagePrice': 0.0,
#    'LeisureHomeTotalPrice': 0.0,
#    'PrivateHomePricing': 0.0,
#    'MaintenanceFee': 0.0,
#    'FinancingFeeInterestOnly': 0.0,
#    'TotalCharges1': 0.0,
#    'FinancingFeeTotal': 0.0,
#    'TotalCharges2': 0.0,
#    'PlotShareFee': 0.0,
#    'WaterFee': None,
#    'OtherFees': 0.0,
#    'DiscountPercentageLoan': 0.0,
#    'LoanPrice': 0.0,
#    'PricePerSqMLoan': 0.0,
#    'PriceWhenFullPayment': 0.0,
#    'DiscountWhenFullPayment': 0.0,
#    'PricePerSqMFullPayment': 0.0,
#    'PaymentOptions': None,
#    'PaymentOptionsKey': None,
#    'CrmDataApproved': True,
#    'SeoUrl': None,
#    'NumberOfRoomsFrom': 1,
#    'NumberOfRoomsTo': 1,
#    'KitchenSize': 0.0,
#    'KitchenType': None,
#    'Sauna': None,
#    'SaunaKey': None,
#    'Balcony': 'Áno',
#    'BalconyKey': 'True',
#    'BalconySize': 6.35,
#    'Terrace': None,
#    'TerraceKey': None,
#    'FirePlace': None,
#    'FirePlaceKey': None,
#    'TerraceSize': 0.0,
#    'BathroomType': None,
#    'WindowsOrientation': 'Z',
#    'ProductItemNonDebtAndPlotShareRedemptionPrice': None,
#    'ProductItemNonDebtAndAlterationOrDecorationPrice': None,
#    'ProductItemNonDebtAndPlotShareRedemptionPriceAndAltOrDecPrice': None,
#    'ProductItemForRent': False,
#    'ProductItemForSale': True,
#    'ProductItemRentDeposit': None,
#    'ProductItemMonthlyRent': None,
#    'ProductItemRentalStatusKey': None,
#    'ProductItemRentalStatus': None,
#    'TransformerMinNumberOfRooms': None,
#    'TransformerMaxNumberOfRooms': None,
#    'TransformerMinSize': None,
#    'TransformerMaxSize': None,
#    'TransformerMinPrice': None,
#    'TransformerMaxPrice': None,
#    'TransformerEndDate': None,
#    'OpenInfo1': '1-izbový byt v novostavbe s lodžiou na ulici Mlynské Nivy, Ružinov',
#    'OpenInfo2': 'Renomovaná stavebno-developerská spoločnosť YIT Slovakia ponúka na predaj nový  1 - izbový byt v novostavbe s lodžiou a pivničnou kobkou v cene v blízkosti centra, na ulici Mlynské Nivy, BA II – Ružinov.\n\nBYT:\n\nSvetlý, doteraz ešte nikým neobývaný 1 - izbový byt sa nachádza v novostavbe bytového komplexu NUPPU v etape Nuppu 6 - Orkidea (predpokladané odovzdanie do užívania jeseň 2021) na rozhraní ulíc Mlynské Nivy a Hraničná, v obľúbenej lokalite Ružinov. \n\nTento byt sa nachádza na 6./7. poschodí. Bytový dom je z monolitu zateplený, priečky v byte sú tehlové. Bytový dom má tri samostatné vchody na čip, v každom vchode je výťah. Byt pozostáva z 1 obytnej miestnosti (obývacia izba s kuchynským kútom) a príslušenstva - chodba, kúpeľňa s WC, lodžia a pivnica. Lodžia má výmeru 6,35 m2.  K bytu prislúcha  pivničná kobka umiestnená na prízemí bytového domu o veľkosti 2,29 m2. Celková úžitková plocha bytu bez plochy lodžie a  je 40,42 m2. \n\nByt má veľké plastové okná a balkónové dvere s predprípravou na vonkajšie hliníkové žalúzie. Orientácia bytu je na západ.\n\nDISPOZIČNÉ RIEŠENIE A VYBAVENIE BYTU:\n\nVstupná chodba (7,41m2), kúpeľňa s WC (5,28 m2), obývacia izba s kuchynským kútom (27,73 m2) a lodžia (6,35 m2).\n\nVybavenie bytu je v dokončenom modernom štandarde: bezpečnostné vstupné dvere Sherlock, plastové okná s izolačným trojskom, laminátová plávajúca podlaha EGGER 7 mm v izbách a na chodbe, interiérové dvere s obložkovou zárubňou s kovaním Tupai, v kúpeľni je keramický obklad, gresová dlažba a kúpeľňová sanita zn. Laufen a Grohe – WC, smaltovaná vaňa a keramické umývadlo s batériami a príprava na napojenie práčky. V byte je predpríprava pre klimatizáciu (prieraz v stene na umiestnenie vonkajšej jednotky na balkóne). Zásuvky a spínače zn. Legrand, domový vrátnik (audiotelefón), vykurovanie je riešené centrálnou dodávkou tepla,  vykurovacie telesá sú doskové a v kúpeľni je rebríkový radiátor. V štandarde je kompletná predpríprava na montáž kuchynskej linky a exteriérových žalúzií. V byte sú rozvody pre TV a optický internet. Súčasťou štandardu sú aj tri senzory smart bývania – na vstupných dverách do bytu, na dverách do pivničnej kobky a na poštovej schránke. Ich cieľom je upozorniť na akýkoľvek pohyb, ktorý senzor zaznamenáva.\n \nBYTOVÝ DOM:\n\nBytový dom je súčasťou rozsiahleho areálu – bytového komplexu NUPPU, ktorý sa postupne napĺňa novými obyvateľmi. Priamo pod oknami bytového domu sa nachádza takmer 2 hektárový spoločný dvor s množstvom zelene – zachovanej pôvodnej a novovysadenej so záhradnými úpravami a multifunkčné zóny – workoutové ihrisko, grilovacia zóna, detské ihriská, výbeh pre psov a zelené zóny s lavičkami a knižnou búdkou. Majiteľom bytov je k dispozícii aj spoločná klubovňa na prízemní každého bytového domu a niekoľko obchodných prevádzok. Súčasťou celého areálu sú nabíjacie stanice pre elektromobily, BalíkoBOX a komunitný carsharing, ktorý môžu využívať výlučne majitelia bytov NUPPU. Areál disponuje aj parkovacími státiami, ktoré sú určené výhradne pre návštevy bytových domov v komplexe.\n\nLOKALITA A OBČIANSKA VYBAVENOSŤ:\n\nTichá a pokojná lokalita s prevažne rodinnými domami má výbornú dostupnosť dôležitých dopravných uzlov a disponuje výbornou občianskou vybavenosťou - v pešej dostupnosti sa nachádzajú obchody, reštaurácie, posilňovňa, pošta, OC Retro. Veľké nákupné centrá do 5 km – Centrál, Eurovea, Aupark, Avion, rýchle napojenie na obchvat, blízko na letisko. Priamo pri areáli je novovybudovaná zastávka MHD. \nMESAČNÉ NÁKLADY:\n\nPredpokladané mesačné náklady sú 130 EUR/1 osobu, každá ďalšia osoba približne + 30,- € mesačne + elektrina, TV a internet\n \nVÝHODY BYTU:\n- svetlý byt v novostavbe s lodžiou\n- predpokladané odovzdanie na jeseň 2021\n- optický internet\n- nízke mesačné náklady\n- dobrá občianska vybavenosť\n- vysoká kvalita použitých stavebných materiálov\n- rozsiahly zelený areál s možnosťou športového aj rekreačného vyžitia\n- pivničná kobka v cene\n\nPovinnosť ...
#    'OpenInfo3': '© COPYRIGHT YIT Slovakia a.s. – Fotografie, obrázky a texty sú autorským dielom a majetkom YIT Slovakia a.s.',
#    'Release': None,
#    'ApartmentConditions': None,
#    'ApartmentConditionsKey': None,
#    'Pets': None,
#    'PetsKey': None,
#    'Landlord': None,
#    'LandlordKey': None,
#    'Fdr': None,
#    'ProjectId': '1-IIWWFF',
#    'ProjectCRMId': '1-IIWWFF',
#    'ProjectLongTitle': None,
#    'ProjectShortTitle': 'NUPPU - Orkidea',
#    'ProjectNameFromCrm': 'NUPPU - Orkidea',
#    'ProjectBusinessSegment': 'Bývanie',
#    'ProjectBusinessSegmentKey': 'Housing',
#    'ProjectAreaMarketingName': None,
#    'ProjectSiteCity': 'bratislava',
#    'ProjectSiteAddress': 'Hraničná 28, 28A, 28B',
#    'ProjectCountryCode': 'SK',
#    'ProjectCountryCodeKey': 'SK',
#    'ProjectSiteCountry': 'SK',
#    'ProjectSiteCountryKey': 'SK',
#    'ProjectDistrict': 'Bratislava II',
#    'ProjectMarketingName': 'NUPPU - Orkidea',
#    'ProjectMarketingHeadline': 'Orkidea',
#    'ProjectMarketingDescription': 'Bytové domy NUPPU majú podobnú kompozíciu, no predsa je každý originálny. Líšia sa farbou a fínskym názvom kvetu. Šiestou etapou je NUPPU Orkidea ktorá poskytne 98 bytových jednotiek na 8 nadzemných podlažiach.',
#    'ProjectCoordinatesLatitude': 48.143809,
#    'ProjectCoordinatesLongitude': 17.158374,
#    'ProjectNumberOfApartments': 98,
#    'ProjectNumberOfSellableParkingPlaces': None,
#    'ProjectNumberOfOtherParkingPlaces': None,
#    'ProjectAvailableParkingPlaces': 0,
#    'ProjectCommunications': None,
#    'ProjectHeatingSystem': None,
#    'ProjectLocationOfParkingLots': None,
#    'ProjectVentilationSystem': None,
#    'ProjectStatus': 'Building ready',
#    'ProjectStatusKey': 'BuildingReady',
#    'WebProjectStatus': 'Skolaudovaný ',
#    'WebProjectStatusKey': 'ReadyToMoveIn',
#    'WebProjectStatusCssClass': 's-ready',
#    'ProjectApartmentSurfaceTotal': 0.0,
#    'ProjectBusinessPremisesSurfaceTotal': 0.0,
#    'ProjectTranslationApproved': None,
#    'ProjectLocality': 'Bratislava',
#    'ProjectSalesOfficeKey': 'BRA',
#    'ProjectSalesOfficeKeyKey': None,
#    'ProjectFinishingType': None,
#    'ProjectCommonSpaces': None,
#    'ProjectEnergyClass': None,
#    'ProjectParkingPlaceAdditionalInfo': None,
#    'ProjectLeisureHomeBusinessPartner': None,
#    'ProjectSchemeForLoanPayment': None,
#    'ProjectPlotOwnership': None,
#    'ProjectPlotOwnershipCvl': None,
#    'ProjectPlotOwnershipCvlKey': None,
#    'ProjectPlotRent': 0.0,
#    'ProjectPlotSize': 0.0,
#    'ProjectFinancingMethod': None,
#    'ProjectB2BNewConstruction': None,
#    'ProjectB2BNewConstructionKey': None,
#    'ProjectB2BCompletionYear': None,
#    'ProjectB2BCompletionDate': None,
#    'ProjectB2BEstimatedCompletion': None,
#    'ProjectB2BAreaMin': None,
#    'ProjectB2BAreaMax': None,
#    'SubProjectId': '1-JGQHPD',
#    'SubProjectName': '6.apartments',
#    'SubProjectBuildingType': 'Bytový dom',
#    'SubProjectBuildingTypeKey': 'BlockOfFlats',
#    'SubProjectElevator': 'Áno',
#    'SubProjectElevatorKey': 'True',
#    'SubProjectNumberOfFloors': 8,
#    'SubProjectCrmDataApproved': True,
#    'SubProjectPimDataApproved': 'Záverečný',
#    'SubProjectPimDataApprovedKey': 'Final',
#    'SubProjectPriceCommentsField': None,
#    'SubProjectCrmId': '1-JGQHPD',
#    'SubProjectConceptFilter': None,
#    'SubProjectConceptFilterKey': None,
#    'SubProjectConceptFilterAndLabel': None,
#    'SubProjectConceptFilterAndLabelKey': None,
#    'SubProjectForRent': None,
#    'SubProjectForSale': None,
#    'Urls': None,
#    'CompletionDate': '2022-03-31T00:00:00Z',
#    'Address': 'Bratislava II | Hraničná 28, 28A, 28B, 82105 bratislava',
#    'CmsFloorNumberOfTotalFloors': '7/8',
#    'CmsB2BProductItemSize': '40.4',
#    'CmsTransformerNumberOfRooms': '1',
#    'CmsTransformerNumberOfRuComRooms': None,
#    'CmsTransformerTotalAreaSize': '46,77',
#    'CmsTransformerKitchenSize': '0',
#    'CmsTransformerLivingAreaSize': '40,4',
#    'CmsTransformerPriceWhenFullPayment': '0',
#    'ApartmentId': '1-JGQXDT',
#    '_Locality': 'Bratislava',
#    '_AvailabilityStatusText': 'Voľný',
#    '_AvailabilityStatusKey': 'Free',
#    '_AvailabilityStatusCssClass': 'free',
#    '_FloorPlanImageUrl': 'https://res.cloudinary.com/yit/image/upload/q_auto:eco,f_auto,fl_lossy,w_700,c_limit/v1637248381/389348.jpg',
#    '_FloorPlanLargeImageUrl': 'https://res.cloudinary.com/yit/image/upload/q_auto:eco,f_auto,fl_lossy,w_1920,c_limit/v1637248381/389348.jpg',
#    '_HasFloorPlan': True,
#    '_NextShowingText': None,
#    '_CampaignBadge': None,
#    '_ProjectBuildingTypes': 'Bytový dom',
#    '_Buttons': [],
#    '_Transformer': False,
#    '_Badges': [{'Title': 'Pivničná kobka v cene',
#      'Icon': 'https://res.cloudinary.com/yit/image/upload/q_auto:eco,f_auto,fl_lossy,w_150,c_limit/v1591265936/292162.jpg'},
#     {'Title': 'Skvelá ponuka',
#      'Icon': 'https://res.cloudinary.com/yit/image/upload/q_auto:eco,f_auto,fl_lossy,w_150,c_limit/v1568879127/245350.jpg'},
#     {'Title': 'Lodžia / Priestranný balkón',
#      'Icon': 'https://res.cloudinary.com/yit/image/upload/q_auto:eco,f_auto,fl_lossy,w_150,c_limit/v1568879129/245351.jpg'}],
#    '_LayoutType': None}},
#  {'Id': '1-JGQXI9',
#   'Type': None,
#   'Score': 0.0,
#   'Fields': {'_Url': '/predaj-bytov/bratislava/ruzinov/nuppu/nuppu-orkidea/1-jgqxi9',
#    'ApartmentNumber': 'F 373',
#    'ApartmentB2BNumber': None,
#    'ReservationStatus': 'Voľný',
#    'ReservationStatusKey': 'Free',
#    'BuildingType': 'Bytový dom',
#    'BuildingTypeKey': 'BlockOfFlats',
#    'ApartmentType': 'Byt',
#    'AreaId': None,
#    'CrmId': '1-JGQXI9',
#    'MarketingHeadline': None,
#    'MarketingDescription': None,
#    'AdditionalInformation': None,
#    'FloorNumber': '7',
#    'FloorNumberCorrectedFrom': 7,
#    'FloorNumberCorrectedTo': None,
#    'MarketingTag': None,
#    'MarketingTagKey': None,
#    'NumberOfRooms': '1',
#    'NumberOfRuComRooms': None,
#    'FloorsInApartment': None,
#    'ApartmentSize': 37.1,
#    'ProductItemSizeFrom': None,
#    'ProductItemSizeTo': None,
#    'OtherAreaSize': 0.0,
#    'TotalAreaSize': 42.96,
#    'ApartmentAddress': 'Hraničná 28 A, B, C F 373',
#    'FinishingType': None,
#    'SalesPrice': 165964.8,
#    'DebtShare': 27660.8,
#    'NonDebtPrice': 138304.0,
#    'SalesPricePerSquare': 4474.65085,
#    'NonDebtPricePerSquare': 0.0,
#    'PlotShareRedemptionPrice': 0.0,
#    'DecorationPackagePrice': 0.0,
#    'LeisureHomeTotalPrice': 0.0,
#    'PrivateHomePricing': 0.0,
#    'MaintenanceFee': 0.0,
#    'FinancingFeeInterestOnly': 0.0,
#    'TotalCharges1': 0.0,
#    'FinancingFeeTotal': 0.0,
#    'TotalCharges2': 0.0,
#    'PlotShareFee': 0.0,
#    'WaterFee': None,
#    'OtherFees': 0.0,
#    'DiscountPercentageLoan': 0.0,
#    'LoanPrice': 0.0,
#    'PricePerSqMLoan': 0.0,
#    'PriceWhenFullPayment': 0.0,
#    'DiscountWhenFullPayment': 0.0,
#    'PricePerSqMFullPayment': 0.0,
#    'PaymentOptions': None,
#    'PaymentOptionsKey': None,
#    'CrmDataApproved': True,
#    'SeoUrl': None,
#    'NumberOfRoomsFrom': 1,
#    'NumberOfRoomsTo': 1,
#    'KitchenSize': 0.0,
#    'KitchenType': None,
#    'Sauna': None,
#    'SaunaKey': None,
#    'Balcony': 'Áno',
#    'BalconyKey': 'True',
#    'BalconySize': 5.87,
#    'Terrace': None,
#    'TerraceKey': None,
#    'FirePlace': None,
#    'FirePlaceKey': None,
#    'TerraceSize': 0.0,
#    'BathroomType': None,
#    'WindowsOrientation': 'JV',
#    'ProductItemNonDebtAndPlotShareRedemptionPrice': None,
#    'ProductItemNonDebtAndAlterationOrDecorationPrice': None,
#    'ProductItemNonDebtAndPlotShareRedemptionPriceAndAltOrDecPrice': None,
#    'ProductItemForRent': False,
#    'ProductItemForSale': True,
#    'ProductItemRentDeposit': None,
#    'ProductItemMonthlyRent': None,
#    'ProductItemRentalStatusKey': None,
#    'ProductItemRentalStatus': None,
#    'TransformerMinNumberOfRooms': None,
#    'TransformerMaxNumberOfRooms': None,
#    'TransformerMinSize': None,
#    'TransformerMaxSize': None,
#    'TransformerMinPrice': None,
#    'TransformerMaxPrice': None,
#    'TransformerEndDate': None,
#    'OpenInfo1': '1-izbový byt s lodžiou v novostavbe na ulici Mlynské Nivy, Ružinov',
#    'OpenInfo2': 'Renomovaná stavebno-developerská spoločnosť YIT Slovakia ponúka na predaj nový 1 - izbový byt v novostavbe s  lodžiou a pivničnou kobkou v cene v blízkosti centra, na ulici Mlynské Nivy, BA II – Ružinov.\n\nBYT:\n\nSvetlý, doteraz ešte nikým neobývaný 1 - izbový byt sa nachádza v novostavbe bytového komplexu NUPPU v etape Nuppu 6 – Orkidea (predpokladaná kolaudácia a odovzdanie na jeseň 2021) na rozhraní ulíc Mlynské Nivy a Hraničná, v obľúbenej lokalite Ružinov. \n\nTento byt sa nachádza na 6./7. poschodí. Bytový dom je z monolitu zateplený, priečky v byte sú tehlové. Bytový dom má tri samostatné vchody na čip, v každom vchode je výťah. Byt pozostáva z 1 obytnej miestností (obývacia izba s kuchynským kútom) a príslušenstva - chodba, kúpeľňa s WC, lodžia a pivnica. Lodžia má výmeru 5,87 m2. K bytu prislúcha aj pivničná kobka umiestnená na prízemí bytového domu o veľkosti 2,14 m2. Celková úžitková plocha bytu bez plochy lodžie a pivnice je 37,09 m2. \n\nByt je veľmi svetlý – má veľké plastové okná a balkónové dvere s predprípravou na vonkajšie hliníkové žalúzie. Orientácia bytu je na východ.\n\nDISPOZIČNÉ RIEŠENIE A VYBAVENIE BYTU:\n\nVeľká vstupná chodba (6,87 m2), kúpeľňa s vaňou a WC (4,96 m2), obývacia izba s kuchynským kútom (25,26 m2), lodžia (5,87 m2).\n\nVybavenie bytu je v dokončenom modernom štandarde: bezpečnostné vstupné dvere Sherlock, plastové okná s izolačným trojskom, laminátová plávajúca podlaha EGGER 7 mm v izbách a na chodbe, interiérové dvere s obložkovou zárubňou s kovaním Tupai, v kúpeľni je keramický obklad, gresová dlažba a kúpeľňová sanita zn. Laufen a Grohe – WC, smaltovaná vaňa a keramické umývadlo s batériami a príprava na napojenie práčky. V byte je predpríprava pre klimatizáciu (prieraz v stene na umiestnenie vonkajšej jednotky na balkóne). Zásuvky a spínače zn. Legrand, domový vrátnik (audiotelefón), vykurovanie je riešené centrálnou dodávkou tepla,  vykurovacie telesá sú doskové a v kúpeľni je rebríkový radiátor. V štandarde je kompletná predpríprava na montáž kuchynskej linky a exteriérových žalúzií. V byte sú rozvody pre TV a optický internet. Súčasťou štandardu sú aj tri senzory smart bývania – na vstupných dverách do bytu, na dverách do pivničnej kobky a na poštovej schránke. Ich cieľom je upozorniť majiteľa na akýkoľvek pohyb, ktorý senzor zaznamenáva\n \nBYTOVÝ DOM:\n\nBytový dom je súčasťou rozsiahleho areálu – bytového komplexu NUPPU, ktorý sa postupne napĺňa novými obyvateľmi. Priamo pod oknami bytového domu sa nachádza takmer 2 hektárový spoločný dvor s množstvom zelene – zachovanej pôvodnej a novovysadenej so záhradnými úpravami a multifunkčné zóny – workoutové ihrisko, grilovacia zóna, detské ihriská, výbeh pre psov a zelené zóny s lavičkami a knižnou búdkou. Majiteľom bytov je k dispozícii aj spoločná klubovňa na prízemní každého bytového domu a niekoľko obchodných prevádzok. Súčasťou celého areálu sú nabíjacie stanice pre elektromobily, BalíkoBOX a komunitný carsharing, ktorý môžu využívať výlučne majitelia bytov NUPPU. Areál disponuje aj parkovacími státiami, ktoré sú určené výhradne pre návštevy bytových domov v komplexe.\n\nLOKALITA A OBČIANSKA VYBAVENOSŤ:\n\nTichá a pokojná lokalita s prevažne rodinnými domami má výbornú dostupnosť dôležitých dopravných uzlov a disponuje výbornou občianskou vybavenosťou - v pešej dostupnosti sa nachádzajú obchody, reštaurácie, posilňovňa, pošta, OC Retro. Veľké nákupné centrá do 5 km – Centrál, Eurovea, Aupark, Avion, rýchle napojenie na obchvat, blízko na letisko. Priamo pri areáli je novovybudovaná zastávka MHD. \nMESAČNÉ NÁKLADY:\n\nPredpokladané mesačné náklady sú 130 EUR/1 osobu, každá ďalšia osoba približne + 30,- € mesačne + elektrina, TV a internet\n \nVÝHODY BYTU:\n\n• svetlý byt v novostavbe s lodžiou\n• predpokladaná kolaudácia a odovzdanie na jeseň 2021\n• optický internet\n• nízke mesačné náklady\n• dobrá občianska vybavenosť\n• vysoká kvalita použitých stavebných materiálov\n• rozsiahly zelený areál s možnosťou špo ...
#    'OpenInfo3': '© COPYRIGHT YIT Slovakia a.s. – Fotografie, obrázky a texty sú autorským dielom a majetkom YIT Slovakia a.s.',
#    'Release': None,
#    'ApartmentConditions': None,
#    'ApartmentConditionsKey': None,
#    'Pets': None,
#    'PetsKey': None,
#    'Landlord': None,
#    'LandlordKey': None,
#    'Fdr': None,
#    'ProjectId': '1-IIWWFF',
#    'ProjectCRMId': '1-IIWWFF',
#    'ProjectLongTitle': None,
#    'ProjectShortTitle': 'NUPPU - Orkidea',
#    'ProjectNameFromCrm': 'NUPPU - Orkidea',
#    'ProjectBusinessSegment': 'Bývanie',
#    'ProjectBusinessSegmentKey': 'Housing',
#    'ProjectAreaMarketingName': None,
#    'ProjectSiteCity': 'bratislava',
#    'ProjectSiteAddress': 'Hraničná 28, 28A, 28B',
#    'ProjectCountryCode': 'SK',
#    'ProjectCountryCodeKey': 'SK',
#    'ProjectSiteCountry': 'SK',
#    'ProjectSiteCountryKey': 'SK',
#    'ProjectDistrict': 'Bratislava II',
#    'ProjectMarketingName': 'NUPPU - Orkidea',
#    'ProjectMarketingHeadline': 'Orkidea',
#    'ProjectMarketingDescription': 'Bytové domy NUPPU majú podobnú kompozíciu, no predsa je každý originálny. Líšia sa farbou a fínskym názvom kvetu. Šiestou etapou je NUPPU Orkidea ktorá poskytne 98 bytových jednotiek na 8 nadzemných podlažiach.',
#    'ProjectCoordinatesLatitude': 48.143809,
#    'ProjectCoordinatesLongitude': 17.158374,
#    'ProjectNumberOfApartments': 98,
#    'ProjectNumberOfSellableParkingPlaces': None,
#    'ProjectNumberOfOtherParkingPlaces': None,
#    'ProjectAvailableParkingPlaces': 0,
#    'ProjectCommunications': None,
#    'ProjectHeatingSystem': None,
#    'ProjectLocationOfParkingLots': None,
#    'ProjectVentilationSystem': None,
#    'ProjectStatus': 'Building ready',
#    'ProjectStatusKey': 'BuildingReady',
#    'WebProjectStatus': 'Skolaudovaný ',
#    'WebProjectStatusKey': 'ReadyToMoveIn',
#    'WebProjectStatusCssClass': 's-ready',
#    'ProjectApartmentSurfaceTotal': 0.0,
#    'ProjectBusinessPremisesSurfaceTotal': 0.0,
#    'ProjectTranslationApproved': None,
#    'ProjectLocality': 'Bratislava',
#    'ProjectSalesOfficeKey': 'BRA',
#    'ProjectSalesOfficeKeyKey': None,
#    'ProjectFinishingType': None,
#    'ProjectCommonSpaces': None,
#    'ProjectEnergyClass': None,
#    'ProjectParkingPlaceAdditionalInfo': None,
#    'ProjectLeisureHomeBusinessPartner': None,
#    'ProjectSchemeForLoanPayment': None,
#    'ProjectPlotOwnership': None,
#    'ProjectPlotOwnershipCvl': None,
#    'ProjectPlotOwnershipCvlKey': None,
#    'ProjectPlotRent': 0.0,
#    'ProjectPlotSize': 0.0,
#    'ProjectFinancingMethod': None,
#    'ProjectB2BNewConstruction': None,
#    'ProjectB2BNewConstructionKey': None,
#    'ProjectB2BCompletionYear': None,
#    'ProjectB2BCompletionDate': None,
#    'ProjectB2BEstimatedCompletion': None,
#    'ProjectB2BAreaMin': None,
#    'ProjectB2BAreaMax': None,
#    'SubProjectId': '1-JGQHPD',
#    'SubProjectName': '6.apartments',
#    'SubProjectBuildingType': 'Bytový dom',
#    'SubProjectBuildingTypeKey': 'BlockOfFlats',
#    'SubProjectElevator': 'Áno',
#    'SubProjectElevatorKey': 'True',
#    'SubProjectNumberOfFloors': 8,
#    'SubProjectCrmDataApproved': True,
#    'SubProjectPimDataApproved': 'Záverečný',
#    'SubProjectPimDataApprovedKey': 'Final',
#    'SubProjectPriceCommentsField': None,
#    'SubProjectCrmId': '1-JGQHPD',
#    'SubProjectConceptFilter': None,
#    'SubProjectConceptFilterKey': None,
#    'SubProjectConceptFilterAndLabel': None,
#    'SubProjectConceptFilterAndLabelKey': None,
#    'SubProjectForRent': None,
#    'SubProjectForSale': None,
#    'Urls': None,
#    'CompletionDate': '2022-03-31T00:00:00Z',
#    'Address': 'Bratislava II | Hraničná 28, 28A, 28B, 82105 bratislava',
#    'CmsFloorNumberOfTotalFloors': '7/8',
#    'CmsB2BProductItemSize': '37.1',
#    'CmsTransformerNumberOfRooms': '1',
#    'CmsTransformerNumberOfRuComRooms': None,
#    'CmsTransformerTotalAreaSize': '42,96',
#    'CmsTransformerKitchenSize': '0',
#    'CmsTransformerLivingAreaSize': '37,1',
#    'CmsTransformerPriceWhenFullPayment': '0',
#    'ApartmentId': '1-JGQXI9',
#    '_Locality': 'Bratislava',
#    '_AvailabilityStatusText': 'Voľný',
#    '_AvailabilityStatusKey': 'Free',
#    '_AvailabilityStatusCssClass': 'free',
#    '_FloorPlanImageUrl': 'https://res.cloudinary.com/yit/image/upload/q_auto:eco,f_auto,fl_lossy,w_700,c_limit/v1593177654/295800.jpg',
#    '_FloorPlanLargeImageUrl': 'https://res.cloudinary.com/yit/image/upload/q_auto:eco,f_auto,fl_lossy,w_1920,c_limit/v1593177654/295800.jpg',
#    '_HasFloorPlan': True,
#    '_NextShowingText': None,
#    '_CampaignBadge': None,
#    '_ProjectBuildingTypes': 'Bytový dom',
#    '_Buttons': [],
#    '_Transformer': False,
#    '_Badges': [{'Title': 'Pivničná kobka v cene',
#      'Icon': 'https://res.cloudinary.com/yit/image/upload/q_auto:eco,f_auto,fl_lossy,w_150,c_limit/v1591265936/292162.jpg'},
#     {'Title': 'Skvelá ponuka',
#      'Icon': 'https://res.cloudinary.com/yit/image/upload/q_auto:eco,f_auto,fl_lossy,w_150,c_limit/v1568879127/245350.jpg'},
#     {'Title': 'Lodžia / Priestranný balkón',
#      'Icon': 'https://res.cloudinary.com/yit/image/upload/q_auto:eco,f_auto,fl_lossy,w_150,c_limit/v1568879129/245351.jpg'}],
#    '_LayoutType': None}},
#  {'Id': '1-L7J8LA',
#   'Type': None,
#   'Score': 0.0,
#   'Fields': {'_Url': '/predaj-bytov/bratislava/ruzinov/zwirn/zwirn1/1-l7j8la',
#    'ApartmentNumber': 'B3.24',
#    'ApartmentB2BNumber': None,
#    'ReservationStatus': 'Voľný',
#    'ReservationStatusKey': 'Free',
#    'BuildingType': 'Bytový dom',
#    'BuildingTypeKey': 'BlockOfFlats',
#    'ApartmentType': 'Byt',
#    'AreaId': None,
#    'CrmId': '1-L7J8LA',
#    'MarketingHeadline': 'V cene je zahrnutá pivničná kobka a bytový štandard (podlaha, interiérové a vstupné dvere, dlažba, obklady, sanita).',
#    'MarketingDescription': None,
#    'AdditionalInformation': None,
#    'FloorNumber': '2.NP',
#    'FloorNumberCorrectedFrom': 2,
#    'FloorNumberCorrectedTo': None,
#    'MarketingTag': None,
#    'MarketingTagKey': None,
#    'NumberOfRooms': '1',
#    'NumberOfRuComRooms': None,
#    'FloorsInApartment': None,
#    'ApartmentSize': 35.7,
#    'ProductItemSizeFrom': None,
#    'ProductItemSizeTo': None,
#    'OtherAreaSize': 0.0,
#    'TotalAreaSize': 40.68,
#    'ApartmentAddress': 'Svätoplukova B3.24',
#    'FinishingType': None,
#    'SalesPrice': 196398.0,
#    'DebtShare': 32733.0,
#    'NonDebtPrice': 163665.0,
#    'SalesPricePerSquare': 5501.34,
#    'NonDebtPricePerSquare': 0.0,
#    'PlotShareRedemptionPrice': 0.0,
#    'DecorationPackagePrice': 0.0,
#    'LeisureHomeTotalPrice': 0.0,
#    'PrivateHomePricing': 0.0,
#    'MaintenanceFee': 0.0,
#    'FinancingFeeInterestOnly': 0.0,
#    'TotalCharges1': 0.0,
#    'FinancingFeeTotal': 0.0,
#    'TotalCharges2': 0.0,
#    'PlotShareFee': 0.0,
#    'WaterFee': None,
#    'OtherFees': 0.0,
#    'DiscountPercentageLoan': 0.0,
#    'LoanPrice': 0.0,
#    'PricePerSqMLoan': 0.0,
#    'PriceWhenFullPayment': 0.0,
#    'DiscountWhenFullPayment': 0.0,
#    'PricePerSqMFullPayment': 0.0,
#    'PaymentOptions': None,
#    'PaymentOptionsKey': None,
#    'CrmDataApproved': True,
#    'SeoUrl': None,
#    'NumberOfRoomsFrom': 1,
#    'NumberOfRoomsTo': 1,
#    'KitchenSize': 0.0,
#    'KitchenType': None,
#    'Sauna': None,
#    'SaunaKey': None,
#    'Balcony': 'Áno',
#    'BalconyKey': 'True',
#    'BalconySize': 4.98,
#    'Terrace': 'Nie',
#    'TerraceKey': 'False',
#    'FirePlace': None,
#    'FirePlaceKey': None,
#    'TerraceSize': 0.0,
#    'BathroomType': None,
#    'WindowsOrientation': 'JV',
#    'ProductItemNonDebtAndPlotShareRedemptionPrice': None,
#    'ProductItemNonDebtAndAlterationOrDecorationPrice': None,
#    'ProductItemNonDebtAndPlotShareRedemptionPriceAndAltOrDecPrice': None,
#    'ProductItemForRent': False,
#    'ProductItemForSale': True,
#    'ProductItemRentDeposit': None,
#    'ProductItemMonthlyRent': None,
#    'ProductItemRentalStatusKey': None,
#    'ProductItemRentalStatus': None,
#    'TransformerMinNumberOfRooms': None,
#    'TransformerMaxNumberOfRooms': None,
#    'TransformerMinSize': None,
#    'TransformerMaxSize': None,
#    'TransformerMinPrice': None,
#    'TransformerMaxPrice': None,
#    'TransformerEndDate': None,
#    'OpenInfo1': None,
#    'OpenInfo2': None,
#    'OpenInfo3': None,
#    'Release': None,
#    'ApartmentConditions': None,
#    'ApartmentConditionsKey': None,
#    'Pets': None,
#    'PetsKey': None,
#    'Landlord': None,
#    'LandlordKey': None,
#    'Fdr': None,
#    'ProjectId': '1-BO15YL',
#    'ProjectCRMId': '1-BO15YL',
#    'ProjectLongTitle': None,
#    'ProjectShortTitle': 'Zwirn 1',
#    'ProjectNameFromCrm': 'Zwirn 1',
#    'ProjectBusinessSegment': 'Bývanie',
#    'ProjectBusinessSegmentKey': 'Housing',
#    'ProjectAreaMarketingName': None,
#    'ProjectSiteCity': 'Bratislava',
#    'ProjectSiteAddress': 'Svätoplukova',
#    'ProjectCountryCode': 'SK',
#    'ProjectCountryCodeKey': 'SK',
#    'ProjectSiteCountry': 'SK',
#    'ProjectSiteCountryKey': 'SK',
#    'ProjectDistrict': 'Bratislava II',
#    'ProjectMarketingName': 'ZWIRN 1',
#    'ProjectMarketingHeadline': 'ZWIRN 1',
#    'ProjectMarketingDescription': 'ZWIRN nadväzuje na bohatú históriu bývalého\npriemyselného areálu cvernovej továrne a začína\nodvíjať nový príbeh, ktorý toto výnimočné miesto\nzmení na vitálnu bratislavskú štvrť pre moderný\nživotný štýl. V prvej etape prinesie spolu 202 bytov a 65 apartmánov.',
#    'ProjectCoordinatesLatitude': 48.147938,
#    'ProjectCoordinatesLongitude': 17.132129,
#    'ProjectNumberOfApartments': 267,
#    'ProjectNumberOfSellableParkingPlaces': None,
#    'ProjectNumberOfOtherParkingPlaces': None,
#    'ProjectAvailableParkingPlaces': 0,
#    'ProjectCommunications': None,
#    'ProjectHeatingSystem': None,
#    'ProjectLocationOfParkingLots': None,
#    'ProjectVentilationSystem': None,
#    'ProjectStatus': 'Sales',
#    'ProjectStatusKey': 'Sales',
#    'WebProjectStatus': 'Vo výstavbe  - Kolaudácia  09/2023 ',
#    'WebProjectStatusKey': 'ToBeReady',
#    'WebProjectStatusCssClass': 's-under-construction',
#    'ProjectApartmentSurfaceTotal': 0.0,
#    'ProjectBusinessPremisesSurfaceTotal': 0.0,
#    'ProjectTranslationApproved': None,
#    'ProjectLocality': 'Bratislava',
#    'ProjectSalesOfficeKey': 'BRA',
#    'ProjectSalesOfficeKeyKey': None,
#    'ProjectFinishingType': None,
#    'ProjectCommonSpaces': None,
#    'ProjectEnergyClass': None,
#    'ProjectParkingPlaceAdditionalInfo': None,
#    'ProjectLeisureHomeBusinessPartner': None,
#    'ProjectSchemeForLoanPayment': None,
#    'ProjectPlotOwnership': None,
#    'ProjectPlotOwnershipCvl': None,
#    'ProjectPlotOwnershipCvlKey': None,
#    'ProjectPlotRent': 0.0,
#    'ProjectPlotSize': 0.0,
#    'ProjectFinancingMethod': None,
#    'ProjectB2BNewConstruction': None,
#    'ProjectB2BNewConstructionKey': None,
#    'ProjectB2BCompletionYear': None,
#    'ProjectB2BCompletionDate': None,
#    'ProjectB2BEstimatedCompletion': None,
#    'ProjectB2BAreaMin': None,
#    'ProjectB2BAreaMax': None,
#    'SubProjectId': '1-L7CNM6',
#    'SubProjectName': '1.apartmentsB',
#    'SubProjectBuildingType': 'Bytový dom',
#    'SubProjectBuildingTypeKey': 'BlockOfFlats',
#    'SubProjectElevator': None,
#    'SubProjectElevatorKey': None,
#    'SubProjectNumberOfFloors': None,
#    'SubProjectCrmDataApproved': True,
#    'SubProjectPimDataApproved': 'Záverečný',
#    'SubProjectPimDataApprovedKey': 'Final',
#    'SubProjectPriceCommentsField': None,
#    'SubProjectCrmId': '1-L7CNM6',
#    'SubProjectConceptFilter': None,
#    'SubProjectConceptFilterKey': None,
#    'SubProjectConceptFilterAndLabel': None,
#    'SubProjectConceptFilterAndLabelKey': None,
#    'SubProjectForRent': None,
#    'SubProjectForSale': None,
#    'Urls': None,
#    'CompletionDate': '2023-09-30T00:00:00Z',
#    'Address': 'Bratislava II | Svätoplukova, 82108 Bratislava',
#    'CmsFloorNumberOfTotalFloors': '2.NP',
#    'CmsB2BProductItemSize': '35.7',
#    'CmsTransformerNumberOfRooms': '1',
#    'CmsTransformerNumberOfRuComRooms': None,
#    'CmsTransformerTotalAreaSize': '40,68',
#    'CmsTransformerKitchenSize': '0',
#    'CmsTransformerLivingAreaSize': '35,7',
#    'CmsTransformerPriceWhenFullPayment': '0',
#    'ApartmentId': '1-L7J8LA',
#    '_Locality': 'Bratislava',
#    '_AvailabilityStatusText': 'Voľný',
#    '_AvailabilityStatusKey': 'Free',
#    '_AvailabilityStatusCssClass': 'free',
#    '_FloorPlanImageUrl': 'https://res.cloudinary.com/yit/image/upload/q_auto:eco,f_auto,fl_lossy,w_700,c_limit/v1612443046/332438.jpg',
#    '_FloorPlanLargeImageUrl': 'https://res.cloudinary.com/yit/image/upload/q_auto:eco,f_auto,fl_lossy,w_1920,c_limit/v1612443046/332438.jpg',
#    '_HasFloorPlan': True,
#    '_NextShowingText': None,
#    '_CampaignBadge': None,
#    '_ProjectBuildingTypes': 'Bytový dom',
#    '_Buttons': [],
#    '_Transformer': False,
#    '_Badges': [],
#    '_LayoutType': None}},
#  {'Id': '1-L7J8M6',
#   'Type': None,
#   'Score': 0.0,
#   'Fields': {'_Url': '/predaj-bytov/bratislava/ruzinov/zwirn/zwirn1/1-l7j8m6',
#    'ApartmentNumber': 'B3.26',
#    'ApartmentB2BNumber': None,
#    'ReservationStatus': 'Voľný',
#    'ReservationStatusKey': 'Free',
#    'BuildingType': 'Bytový dom',
#    'BuildingTypeKey': 'BlockOfFlats',
#    'ApartmentType': 'Byt',
#    'AreaId': None,
#    'CrmId': '1-L7J8M6',
#    'MarketingHeadline': 'V cene je zahrnutá pivničná kobka a bytový štandard (podlaha, interiérové a vstupné dvere, dlažba, obklady, sanita).',
#    'MarketingDescription': None,
#    'AdditionalInformation': None,
#    'FloorNumber': '2.NP',
#    'FloorNumberCorrectedFrom': 2,
#    'FloorNumberCorrectedTo': None,
#    'MarketingTag': None,
#    'MarketingTagKey': None,
#    'NumberOfRooms': '3',
#    'NumberOfRuComRooms': None,
#    'FloorsInApartment': None,
#    'ApartmentSize': 75.3,
#    'ProductItemSizeFrom': None,
#    'ProductItemSizeTo': None,
#    'OtherAreaSize': 0.0,
#    'TotalAreaSize': 86.21,
#    'ApartmentAddress': 'Svätoplukova B3.26',
#    'FinishingType': None,
#    'SalesPrice': 410866.8,
#    'DebtShare': 68477.8,
#    'NonDebtPrice': 342389.0,
#    'SalesPricePerSquare': 5455.67,
#    'NonDebtPricePerSquare': 0.0,
#    'PlotShareRedemptionPrice': 0.0,
#    'DecorationPackagePrice': 0.0,
#    'LeisureHomeTotalPrice': 0.0,
#    'PrivateHomePricing': 0.0,
#    'MaintenanceFee': 0.0,
#    'FinancingFeeInterestOnly': 0.0,
#    'TotalCharges1': 0.0,
#    'FinancingFeeTotal': 0.0,
#    'TotalCharges2': 0.0,
#    'PlotShareFee': 0.0,
#    'WaterFee': None,
#    'OtherFees': 0.0,
#    'DiscountPercentageLoan': 0.0,
#    'LoanPrice': 0.0,
#    'PricePerSqMLoan': 0.0,
#    'PriceWhenFullPayment': 0.0,
#    'DiscountWhenFullPayment': 0.0,
#    'PricePerSqMFullPayment': 0.0,
#    'PaymentOptions': None,
#    'PaymentOptionsKey': None,
#    'CrmDataApproved': True,
#    'SeoUrl': None,
#    'NumberOfRoomsFrom': 3,
#    'NumberOfRoomsTo': 3,
#    'KitchenSize': 0.0,
#    'KitchenType': None,
#    'Sauna': None,
#    'SaunaKey': None,
#    'Balcony': 'Áno',
#    'BalconyKey': 'True',
#    'BalconySize': 10.9,
#    'Terrace': 'Nie',
#    'TerraceKey': 'False',
#    'FirePlace': None,
#    'FirePlaceKey': None,
#    'TerraceSize': 0.0,
#    'BathroomType': None,
#    'WindowsOrientation': 'SZ/JV',
#    'ProductItemNonDebtAndPlotShareRedemptionPrice': None,
#    'ProductItemNonDebtAndAlterationOrDecorationPrice': None,
#    'ProductItemNonDebtAndPlotShareRedemptionPriceAndAltOrDecPrice': None,
#    'ProductItemForRent': False,
#    'ProductItemForSale': True,
#    'ProductItemRentDeposit': None,
#    'ProductItemMonthlyRent': None,
#    'ProductItemRentalStatusKey': None,
#    'ProductItemRentalStatus': None,
#    'TransformerMinNumberOfRooms': None,
#    'TransformerMaxNumberOfRooms': None,
#    'TransformerMinSize': None,
#    'TransformerMaxSize': None,
#    'TransformerMinPrice': None,
#    'TransformerMaxPrice': None,
#    'TransformerEndDate': None,
#    'OpenInfo1': None,
#    'OpenInfo2': None,
#    'OpenInfo3': None,
#    'Release': None,
#    'ApartmentConditions': None,
#    'ApartmentConditionsKey': None,
#    'Pets': None,
#    'PetsKey': None,
#    'Landlord': None,
#    'LandlordKey': None,
#    'Fdr': None,
#    'ProjectId': '1-BO15YL',
#    'ProjectCRMId': '1-BO15YL',
#    'ProjectLongTitle': None,
#    'ProjectShortTitle': 'Zwirn 1',
#    'ProjectNameFromCrm': 'Zwirn 1',
#    'ProjectBusinessSegment': 'Bývanie',
#    'ProjectBusinessSegmentKey': 'Housing',
#    'ProjectAreaMarketingName': None,
#    'ProjectSiteCity': 'Bratislava',
#    'ProjectSiteAddress': 'Svätoplukova',
#    'ProjectCountryCode': 'SK',
#    'ProjectCountryCodeKey': 'SK',
#    'ProjectSiteCountry': 'SK',
#    'ProjectSiteCountryKey': 'SK',
#    'ProjectDistrict': 'Bratislava II',
#    'ProjectMarketingName': 'ZWIRN 1',
#    'ProjectMarketingHeadline': 'ZWIRN 1',
#    'ProjectMarketingDescription': 'ZWIRN nadväzuje na bohatú históriu bývalého\npriemyselného areálu cvernovej továrne a začína\nodvíjať nový príbeh, ktorý toto výnimočné miesto\nzmení na vitálnu bratislavskú štvrť pre moderný\nživotný štýl. V prvej etape prinesie spolu 202 bytov a 65 apartmánov.',
#    'ProjectCoordinatesLatitude': 48.147938,
#    'ProjectCoordinatesLongitude': 17.132129,
#    'ProjectNumberOfApartments': 267,
#    'ProjectNumberOfSellableParkingPlaces': None,
#    'ProjectNumberOfOtherParkingPlaces': None,
#    'ProjectAvailableParkingPlaces': 0,
#    'ProjectCommunications': None,
#    'ProjectHeatingSystem': None,
#    'ProjectLocationOfParkingLots': None,
#    'ProjectVentilationSystem': None,
#    'ProjectStatus': 'Sales',
#    'ProjectStatusKey': 'Sales',
#    'WebProjectStatus': 'Vo výstavbe  - Kolaudácia  09/2023 ',
#    'WebProjectStatusKey': 'ToBeReady',
#    'WebProjectStatusCssClass': 's-under-construction',
#    'ProjectApartmentSurfaceTotal': 0.0,
#    'ProjectBusinessPremisesSurfaceTotal': 0.0,
#    'ProjectTranslationApproved': None,
#    'ProjectLocality': 'Bratislava',
#    'ProjectSalesOfficeKey': 'BRA',
#    'ProjectSalesOfficeKeyKey': None,
#    'ProjectFinishingType': None,
#    'ProjectCommonSpaces': None,
#    'ProjectEnergyClass': None,
#    'ProjectParkingPlaceAdditionalInfo': None,
#    'ProjectLeisureHomeBusinessPartner': None,
#    'ProjectSchemeForLoanPayment': None,
#    'ProjectPlotOwnership': None,
#    'ProjectPlotOwnershipCvl': None,
#    'ProjectPlotOwnershipCvlKey': None,
#    'ProjectPlotRent': 0.0,
#    'ProjectPlotSize': 0.0,
#    'ProjectFinancingMethod': None,
#    'ProjectB2BNewConstruction': None,
#    'ProjectB2BNewConstructionKey': None,
#    'ProjectB2BCompletionYear': None,
#    'ProjectB2BCompletionDate': None,
#    'ProjectB2BEstimatedCompletion': None,
#    'ProjectB2BAreaMin': None,
#    'ProjectB2BAreaMax': None,
#    'SubProjectId': '1-L7CNM6',
#    'SubProjectName': '1.apartmentsB',
#    'SubProjectBuildingType': 'Bytový dom',
#    'SubProjectBuildingTypeKey': 'BlockOfFlats',
#    'SubProjectElevator': None,
#    'SubProjectElevatorKey': None,
#    'SubProjectNumberOfFloors': None,
#    'SubProjectCrmDataApproved': True,
#    'SubProjectPimDataApproved': 'Záverečný',
#    'SubProjectPimDataApprovedKey': 'Final',
#    'SubProjectPriceCommentsField': None,
#    'SubProjectCrmId': '1-L7CNM6',
#    'SubProjectConceptFilter': None,
#    'SubProjectConceptFilterKey': None,
#    'SubProjectConceptFilterAndLabel': None,
#    'SubProjectConceptFilterAndLabelKey': None,
#    'SubProjectForRent': None,
#    'SubProjectForSale': None,
#    'Urls': None,
#    'CompletionDate': '2023-09-30T00:00:00Z',
#    'Address': 'Bratislava II | Svätoplukova, 82108 Bratislava',
#    'CmsFloorNumberOfTotalFloors': '2.NP',
#    'CmsB2BProductItemSize': '75.3',
#    'CmsTransformerNumberOfRooms': '3',
#    'CmsTransformerNumberOfRuComRooms': None,
#    'CmsTransformerTotalAreaSize': '86,21',
#    'CmsTransformerKitchenSize': '0',
#    'CmsTransformerLivingAreaSize': '75,3',
#    'CmsTransformerPriceWhenFullPayment': '0',
#    'ApartmentId': '1-L7J8M6',
#    '_Locality': 'Bratislava',
#    '_AvailabilityStatusText': 'Voľný',
#    '_AvailabilityStatusKey': 'Free',
#    '_AvailabilityStatusCssClass': 'free',
#    '_FloorPlanImageUrl': 'https://res.cloudinary.com/yit/image/upload/q_auto:eco,f_auto,fl_lossy,w_700,c_limit/v1612443050/332440.jpg',
#    '_FloorPlanLargeImageUrl': 'https://res.cloudinary.com/yit/image/upload/q_auto:eco,f_auto,fl_lossy,w_1920,c_limit/v1612443050/332440.jpg',
#    '_HasFloorPlan': True,
#    '_NextShowingText': None,
#    '_CampaignBadge': None,
#    '_ProjectBuildingTypes': 'Bytový dom',
#    '_Buttons': [],
#    '_Transformer': False,
#    '_Badges': [],
#    '_LayoutType': None}},
#  {'Id': '1-L7J8NY',
#   'Type': None,
#   'Score': 0.0,
#   'Fields': {'_Url': '/predaj-bytov/bratislava/ruzinov/zwirn/zwirn1/1-l7j8ny',
#    'ApartmentNumber': 'B3.34',
#    'ApartmentB2BNumber': None,
#    'ReservationStatus': 'Voľný',
#    'ReservationStatusKey': 'Free',
#    'BuildingType': 'Bytový dom',
#    'BuildingTypeKey': 'BlockOfFlats',
#    'ApartmentType': 'Byt',
#    'AreaId': None,
#    'CrmId': '1-L7J8NY',
#    'MarketingHeadline': 'V cene je zahrnutá pivničná kobka a bytový štandard (podlaha, interiérové a vstupné dvere, dlažba, obklady, sanita).',
#    'MarketingDescription': None,
#    'AdditionalInformation': None,
#    'FloorNumber': '3.NP',
#    'FloorNumberCorrectedFrom': 3,
#    'FloorNumberCorrectedTo': None,
#    'MarketingTag': None,
#    'MarketingTagKey': None,
#    'NumberOfRooms': '1',
#    'NumberOfRuComRooms': None,
#    'FloorsInApartment': None,
#    'ApartmentSize': 35.7,
#    'ProductItemSizeFrom': None,
#    'ProductItemSizeTo': None,
#    'OtherAreaSize': 0.0,
#    'TotalAreaSize': 40.68,
#    'ApartmentAddress': 'Svätoplukova B3.34',
#    'FinishingType': None,
#    'SalesPrice': 201660.0,
#    'DebtShare': 33610.0,
#    'NonDebtPrice': 168050.0,
#    'SalesPricePerSquare': 5648.74,
#    'NonDebtPricePerSquare': 0.0,
#    'PlotShareRedemptionPrice': 0.0,
#    'DecorationPackagePrice': 0.0,
#    'LeisureHomeTotalPrice': 0.0,
#    'PrivateHomePricing': 0.0,
#    'MaintenanceFee': 0.0,
#    'FinancingFeeInterestOnly': 0.0,
#    'TotalCharges1': 0.0,
#    'FinancingFeeTotal': 0.0,
#    'TotalCharges2': 0.0,
# ...
#    'CmsTransformerLivingAreaSize': '59,4',
#    'CmsTransformerPriceWhenFullPayment': '0',
#    'ApartmentId': '1-Q47QCV',
#    '_Locality': 'Bratislava',
#    '_AvailabilityStatusText': 'Nezáväzne rezervované',
#    '_AvailabilityStatusKey': 'Reserved',
#    '_AvailabilityStatusCssClass': 'reserved',
#    '_FloorPlanImageUrl': 'https://res.cloudinary.com/yit/image/upload/q_auto:eco,f_auto,fl_lossy,w_700,c_limit/v1633074944/381587.jpg',
#    '_FloorPlanLargeImageUrl': 'https://res.cloudinary.com/yit/image/upload/q_auto:eco,f_auto,fl_lossy,w_1920,c_limit/v1633074944/381587.jpg',
#    '_HasFloorPlan': True,
#    '_NextShowingText': None,
#    '_CampaignBadge': None,
#    '_ProjectBuildingTypes': 'Bytový dom',
#    '_Buttons': [],
#    '_Transformer': False,
#    '_Badges': [],
#    '_LayoutType': None}},
#  {'Id': '1-Q47QF3',
#   'Type': None,
#   'Score': 0.0,
#   'Fields': {'_Url': '/predaj-bytov/bratislava/ruzinov/nuppu/nuppu-magnolia-1/1-q47qf3',
#    'ApartmentNumber': 'L126',
#    'ApartmentB2BNumber': None,
#    'ReservationStatus': 'Nezáväzne rezervované',
#    'ReservationStatusKey': 'Reserved',
#    'BuildingType': 'Bytový dom',
#    'BuildingTypeKey': 'BlockOfFlats',
#    'ApartmentType': 'Apartmán',
#    'AreaId': None,
#    'CrmId': '1-Q47QF3',
#    'MarketingHeadline': None,
#    'MarketingDescription': 'V cene je zahrnutý bytový štandard a čiastočné vnútorné vybavenie (kuchynská linka so vstavanými spotrebičmi, šatník a stropné svietidlá).',
#    'AdditionalInformation': None,
#    'FloorNumber': '2',
#    'FloorNumberCorrectedFrom': 2,
#    'FloorNumberCorrectedTo': None,
#    'MarketingTag': None,
#    'MarketingTagKey': None,
#    'NumberOfRooms': '2',
#    'NumberOfRuComRooms': None,
#    'FloorsInApartment': None,
#    'ApartmentSize': 45.9,
#    'ProductItemSizeFrom': None,
#    'ProductItemSizeTo': None,
#    'OtherAreaSize': 0.0,
#    'TotalAreaSize': 49.76,
#    'ApartmentAddress': 'Hraničná L126',
#    'FinishingType': None,
#    'SalesPrice': 155443.2,
#    'DebtShare': 25907.2,
#    'NonDebtPrice': 129536.0,
#    'SalesPricePerSquare': 3389.51592,
#    'NonDebtPricePerSquare': 0.0,
#    'PlotShareRedemptionPrice': 0.0,
#    'DecorationPackagePrice': 0.0,
#    'LeisureHomeTotalPrice': 0.0,
#    'PrivateHomePricing': 0.0,
#    'MaintenanceFee': 0.0,
#    'FinancingFeeInterestOnly': 0.0,
#    'TotalCharges1': 0.0,
#    'FinancingFeeTotal': 0.0,
#    'TotalCharges2': 0.0,
#    'PlotShareFee': 0.0,
#    'WaterFee': None,
#    'OtherFees': 0.0,
#    'DiscountPercentageLoan': 0.0,
#    'LoanPrice': 0.0,
#    'PricePerSqMLoan': 0.0,
#    'PriceWhenFullPayment': 0.0,
#    'DiscountWhenFullPayment': 0.0,
#    'PricePerSqMFullPayment': 0.0,
#    'PaymentOptions': None,
#    'PaymentOptionsKey': None,
#    'CrmDataApproved': True,
#    'SeoUrl': None,
#    'NumberOfRoomsFrom': 2,
#    'NumberOfRoomsTo': 2,
#    'KitchenSize': 0.0,
#    'KitchenType': None,
#    'Sauna': None,
#    'SaunaKey': None,
#    'Balcony': 'Áno',
#    'BalconyKey': 'True',
#    'BalconySize': 3.9,
#    'Terrace': 'Nie',
#    'TerraceKey': 'False',
#    'FirePlace': None,
#    'FirePlaceKey': None,
#    'TerraceSize': 0.0,
#    'BathroomType': None,
#    'WindowsOrientation': 'J',
#    'ProductItemNonDebtAndPlotShareRedemptionPrice': None,
#    'ProductItemNonDebtAndAlterationOrDecorationPrice': None,
#    'ProductItemNonDebtAndPlotShareRedemptionPriceAndAltOrDecPrice': None,
#    'ProductItemForRent': False,
#    'ProductItemForSale': True,
#    'ProductItemRentDeposit': None,
#    'ProductItemMonthlyRent': None,
#    'ProductItemRentalStatusKey': None,
#    'ProductItemRentalStatus': None,
#    'TransformerMinNumberOfRooms': None,
#    'TransformerMaxNumberOfRooms': None,
#    'TransformerMinSize': None,
#    'TransformerMaxSize': None,
#    'TransformerMinPrice': None,
#    'TransformerMaxPrice': None,
#    'TransformerEndDate': None,
#    'OpenInfo1': None,
#    'OpenInfo2': None,
#    'OpenInfo3': None,
#    'Release': None,
#    'ApartmentConditions': None,
#    'ApartmentConditionsKey': None,
#    'Pets': None,
#    'PetsKey': None,
#    'Landlord': None,
#    'LandlordKey': None,
#    'Fdr': None,
#    'ProjectId': '1-Q3A2IJ',
#    'ProjectCRMId': '1-Q3A2IJ',
#    'ProjectLongTitle': None,
#    'ProjectShortTitle': 'NUPPU - Magnolia 1',
#    'ProjectNameFromCrm': 'NUPPU - Magnolia 1',
#    'ProjectBusinessSegment': 'Bývanie',
#    'ProjectBusinessSegmentKey': 'Housing',
#    'ProjectAreaMarketingName': None,
#    'ProjectSiteCity': 'Bratislava',
#    'ProjectSiteAddress': 'Hraničná',
#    'ProjectCountryCode': 'SK',
#    'ProjectCountryCodeKey': 'SK',
#    'ProjectSiteCountry': 'SK',
#    'ProjectSiteCountryKey': 'SK',
#    'ProjectDistrict': 'Bratislava II',
#    'ProjectMarketingName': 'NUPPU - Magnolia 1',
#    'ProjectMarketingHeadline': 'Magnolia',
#    'ProjectMarketingDescription': 'Bytové domy NUPPU sú si podobné, no predsa je každý originálny. Líšia sa farbou a fínskym názvom kvetu. Magnolia 1 je prvou z etáp, ktorá sa predáva nielen v štandarde, ale už aj s čiastočným vnútorným vybavením. Je to taktiež prvá etapa, kde bude využitá prefabrikácie, ktorá okrem iných výhod preukázateľne znižuje uhlíkovú stopu stavby. Celkovo pozostáva z 95 apartmánov na 7 nadzemných podlažiach.',
#    'ProjectCoordinatesLatitude': 48.1428021904267,
#    'ProjectCoordinatesLongitude': 17.1573798793713,
#    'ProjectNumberOfApartments': 95,
#    'ProjectNumberOfSellableParkingPlaces': None,
#    'ProjectNumberOfOtherParkingPlaces': 83,
#    'ProjectAvailableParkingPlaces': 0,
#    'ProjectCommunications': None,
#    'ProjectHeatingSystem': None,
#    'ProjectLocationOfParkingLots': None,
#    'ProjectVentilationSystem': None,
#    'ProjectStatus': 'Sales',
#    'ProjectStatusKey': 'Sales',
#    'WebProjectStatus': 'Vo výstavbe  - Kolaudácia  08/2023 ',
#    'WebProjectStatusKey': 'ToBeReady',
#    'WebProjectStatusCssClass': 's-under-construction',
#    'ProjectApartmentSurfaceTotal': 0.0,
#    'ProjectBusinessPremisesSurfaceTotal': 0.0,
#    'ProjectTranslationApproved': None,
#    'ProjectLocality': 'Bratislava',
#    'ProjectSalesOfficeKey': 'BRA',
#    'ProjectSalesOfficeKeyKey': None,
#    'ProjectFinishingType': None,
#    'ProjectCommonSpaces': None,
#    'ProjectEnergyClass': None,
#    'ProjectParkingPlaceAdditionalInfo': None,
#    'ProjectLeisureHomeBusinessPartner': None,
#    'ProjectSchemeForLoanPayment': None,
#    'ProjectPlotOwnership': None,
#    'ProjectPlotOwnershipCvl': None,
#    'ProjectPlotOwnershipCvlKey': None,
#    'ProjectPlotRent': 0.0,
#    'ProjectPlotSize': 0.0,
#    'ProjectFinancingMethod': None,
#    'ProjectB2BNewConstruction': None,
#    'ProjectB2BNewConstructionKey': None,
#    'ProjectB2BCompletionYear': None,
#    'ProjectB2BCompletionDate': None,
#    'ProjectB2BEstimatedCompletion': None,
#    'ProjectB2BAreaMin': None,
#    'ProjectB2BAreaMax': None,
#    'SubProjectId': '1-Q3AMYA',
#    'SubProjectName': '11.apartments',
#    'SubProjectBuildingType': 'Bytový dom',
#    'SubProjectBuildingTypeKey': 'BlockOfFlats',
#    'SubProjectElevator': None,
#    'SubProjectElevatorKey': None,
#    'SubProjectNumberOfFloors': None,
#    'SubProjectCrmDataApproved': True,
#    'SubProjectPimDataApproved': 'Záverečný',
#    'SubProjectPimDataApprovedKey': 'Final',
#    'SubProjectPriceCommentsField': None,
#    'SubProjectCrmId': '1-Q3AMYA',
#    'SubProjectConceptFilter': None,
#    'SubProjectConceptFilterKey': None,
#    'SubProjectConceptFilterAndLabel': None,
#    'SubProjectConceptFilterAndLabelKey': None,
#    'SubProjectForRent': None,
#    'SubProjectForSale': None,
#    'Urls': None,
#    'CompletionDate': '2023-08-31T00:00:00Z',
#    'Address': 'Bratislava II | Hraničná, 82105 Bratislava',
#    'CmsFloorNumberOfTotalFloors': '2',
#    'CmsB2BProductItemSize': '45.9',
#    'CmsTransformerNumberOfRooms': '2',
#    'CmsTransformerNumberOfRuComRooms': None,
#    'CmsTransformerTotalAreaSize': '49,76',
#    'CmsTransformerKitchenSize': '0',
#    'CmsTransformerLivingAreaSize': '45,9',
#    'CmsTransformerPriceWhenFullPayment': '0',
#    'ApartmentId': '1-Q47QF3',
#    '_Locality': 'Bratislava',
#    '_AvailabilityStatusText': 'Nezáväzne rezervované',
#    '_AvailabilityStatusKey': 'Reserved',
#    '_AvailabilityStatusCssClass': 'reserved',
#    '_FloorPlanImageUrl': 'https://res.cloudinary.com/yit/image/upload/q_auto:eco,f_auto,fl_lossy,w_700,c_limit/v1629725212/374599.jpg',
#    '_FloorPlanLargeImageUrl': 'https://res.cloudinary.com/yit/image/upload/q_auto:eco,f_auto,fl_lossy,w_1920,c_limit/v1629725212/374599.jpg',
#    '_HasFloorPlan': True,
#    '_NextShowingText': None,
#    '_CampaignBadge': None,
#    '_ProjectBuildingTypes': 'Bytový dom',
#    '_Buttons': [],
#    '_Transformer': False,
#    '_Badges': [],
#    '_LayoutType': None}},
#  {'Id': '1-Q47YAF',
#   'Type': None,
#   'Score': 0.0,
#   'Fields': {'_Url': '/predaj-bytov/bratislava/ruzinov/nuppu/nuppu-magnolia-1/1-q47yaf',
#    'ApartmentNumber': 'L1711',
#    'ApartmentB2BNumber': None,
#    'ReservationStatus': 'Nezáväzne rezervované',
#    'ReservationStatusKey': 'Reserved',
#    'BuildingType': 'Bytový dom',
#    'BuildingTypeKey': 'BlockOfFlats',
#    'ApartmentType': 'Apartmán',
#    'AreaId': None,
#    'CrmId': '1-Q47YAF',
#    'MarketingHeadline': None,
#    'MarketingDescription': 'V cene je zahrnutý bytový štandard a čiastočné vnútorné vybavenie (kuchynská linka so vstavanými spotrebičmi, šatník a stropné svietidlá).',
#    'AdditionalInformation': None,
#    'FloorNumber': '7',
#    'FloorNumberCorrectedFrom': 7,
#    'FloorNumberCorrectedTo': None,
#    'MarketingTag': None,
#    'MarketingTagKey': None,
#    'NumberOfRooms': '1',
#    'NumberOfRuComRooms': None,
#    'FloorsInApartment': None,
#    'ApartmentSize': 28.2,
#    'ProductItemSizeFrom': None,
#    'ProductItemSizeTo': None,
#    'OtherAreaSize': 0.0,
#    'TotalAreaSize': 28.22,
#    'ApartmentAddress': 'Hraničná L1711',
#    'FinishingType': None,
#    'SalesPrice': 121591.2,
#    'DebtShare': 20265.2,
#    'NonDebtPrice': 101326.0,
#    'SalesPricePerSquare': 4308.68887,
#    'NonDebtPricePerSquare': 0.0,
#    'PlotShareRedemptionPrice': 0.0,
#    'DecorationPackagePrice': 0.0,
#    'LeisureHomeTotalPrice': 0.0,
#    'PrivateHomePricing': 0.0,
#    'MaintenanceFee': 0.0,
#    'FinancingFeeInterestOnly': 0.0,
#    'TotalCharges1': 0.0,
#    'FinancingFeeTotal': 0.0,
#    'TotalCharges2': 0.0,
#    'PlotShareFee': 0.0,
#    'WaterFee': None,
#    'OtherFees': 0.0,
#    'DiscountPercentageLoan': 0.0,
#    'LoanPrice': 0.0,
#    'PricePerSqMLoan': 0.0,
#    'PriceWhenFullPayment': 0.0,
#    'DiscountWhenFullPayment': 0.0,
#    'PricePerSqMFullPayment': 0.0,
#    'PaymentOptions': None,
#    'PaymentOptionsKey': None,
#    'CrmDataApproved': True,
#    'SeoUrl': None,
#    'NumberOfRoomsFrom': 1,
#    'NumberOfRoomsTo': 1,
#    'KitchenSize': 0.0,
#    'KitchenType': None,
#    'Sauna': None,
#    'SaunaKey': None,
#    'Balcony': 'Nie',
#    'BalconyKey': 'False',
#    'BalconySize': 0.0,
#    'Terrace': 'Nie',
#    'TerraceKey': 'False',
#    'FirePlace': None,
#    'FirePlaceKey': None,
#    'TerraceSize': 0.0,
#    'BathroomType': None,
#    'WindowsOrientation': 'J',
#    'ProductItemNonDebtAndPlotShareRedemptionPrice': None,
#    'ProductItemNonDebtAndAlterationOrDecorationPrice': None,
#    'ProductItemNonDebtAndPlotShareRedemptionPriceAndAltOrDecPrice': None,
#    'ProductItemForRent': False,
#    'ProductItemForSale': True,
#    'ProductItemRentDeposit': None,
#    'ProductItemMonthlyRent': None,
#    'ProductItemRentalStatusKey': None,
#    'ProductItemRentalStatus': None,
#    'TransformerMinNumberOfRooms': None,
#    'TransformerMaxNumberOfRooms': None,
#    'TransformerMinSize': None,
#    'TransformerMaxSize': None,
#    'TransformerMinPrice': None,
#    'TransformerMaxPrice': None,
#    'TransformerEndDate': None,
#    'OpenInfo1': None,
#    'OpenInfo2': None,
#    'OpenInfo3': None,
#    'Release': None,
#    'ApartmentConditions': None,
#    'ApartmentConditionsKey': None,
#    'Pets': None,
#    'PetsKey': None,
#    'Landlord': None,
#    'LandlordKey': None,
#    'Fdr': None,
#    'ProjectId': '1-Q3A2IJ',
#    'ProjectCRMId': '1-Q3A2IJ',
#    'ProjectLongTitle': None,
#    'ProjectShortTitle': 'NUPPU - Magnolia 1',
#    'ProjectNameFromCrm': 'NUPPU - Magnolia 1',
#    'ProjectBusinessSegment': 'Bývanie',
#    'ProjectBusinessSegmentKey': 'Housing',
#    'ProjectAreaMarketingName': None,
#    'ProjectSiteCity': 'Bratislava',
#    'ProjectSiteAddress': 'Hraničná',
#    'ProjectCountryCode': 'SK',
#    'ProjectCountryCodeKey': 'SK',
#    'ProjectSiteCountry': 'SK',
#    'ProjectSiteCountryKey': 'SK',
#    'ProjectDistrict': 'Bratislava II',
#    'ProjectMarketingName': 'NUPPU - Magnolia 1',
#    'ProjectMarketingHeadline': 'Magnolia',
#    'ProjectMarketingDescription': 'Bytové domy NUPPU sú si podobné, no predsa je každý originálny. Líšia sa farbou a fínskym názvom kvetu. Magnolia 1 je prvou z etáp, ktorá sa predáva nielen v štandarde, ale už aj s čiastočným vnútorným vybavením. Je to taktiež prvá etapa, kde bude využitá prefabrikácie, ktorá okrem iných výhod preukázateľne znižuje uhlíkovú stopu stavby. Celkovo pozostáva z 95 apartmánov na 7 nadzemných podlažiach.',
#    'ProjectCoordinatesLatitude': 48.1428021904267,
#    'ProjectCoordinatesLongitude': 17.1573798793713,
#    'ProjectNumberOfApartments': 95,
#    'ProjectNumberOfSellableParkingPlaces': None,
#    'ProjectNumberOfOtherParkingPlaces': 83,
#    'ProjectAvailableParkingPlaces': 0,
#    'ProjectCommunications': None,
#    'ProjectHeatingSystem': None,
#    'ProjectLocationOfParkingLots': None,
#    'ProjectVentilationSystem': None,
#    'ProjectStatus': 'Sales',
#    'ProjectStatusKey': 'Sales',
#    'WebProjectStatus': 'Vo výstavbe  - Kolaudácia  08/2023 ',
#    'WebProjectStatusKey': 'ToBeReady',
#    'WebProjectStatusCssClass': 's-under-construction',
#    'ProjectApartmentSurfaceTotal': 0.0,
#    'ProjectBusinessPremisesSurfaceTotal': 0.0,
#    'ProjectTranslationApproved': None,
#    'ProjectLocality': 'Bratislava',
#    'ProjectSalesOfficeKey': 'BRA',
#    'ProjectSalesOfficeKeyKey': None,
#    'ProjectFinishingType': None,
#    'ProjectCommonSpaces': None,
#    'ProjectEnergyClass': None,
#    'ProjectParkingPlaceAdditionalInfo': None,
#    'ProjectLeisureHomeBusinessPartner': None,
#    'ProjectSchemeForLoanPayment': None,
#    'ProjectPlotOwnership': None,
#    'ProjectPlotOwnershipCvl': None,
#    'ProjectPlotOwnershipCvlKey': None,
#    'ProjectPlotRent': 0.0,
#    'ProjectPlotSize': 0.0,
#    'ProjectFinancingMethod': None,
#    'ProjectB2BNewConstruction': None,
#    'ProjectB2BNewConstructionKey': None,
#    'ProjectB2BCompletionYear': None,
#    'ProjectB2BCompletionDate': None,
#    'ProjectB2BEstimatedCompletion': None,
#    'ProjectB2BAreaMin': None,
#    'ProjectB2BAreaMax': None,
#    'SubProjectId': '1-Q3AMYA',
#    'SubProjectName': '11.apartments',
#    'SubProjectBuildingType': 'Bytový dom',
#    'SubProjectBuildingTypeKey': 'BlockOfFlats',
#    'SubProjectElevator': None,
#    'SubProjectElevatorKey': None,
#    'SubProjectNumberOfFloors': None,
#    'SubProjectCrmDataApproved': True,
#    'SubProjectPimDataApproved': 'Záverečný',
#    'SubProjectPimDataApprovedKey': 'Final',
#    'SubProjectPriceCommentsField': None,
#    'SubProjectCrmId': '1-Q3AMYA',
#    'SubProjectConceptFilter': None,
#    'SubProjectConceptFilterKey': None,
#    'SubProjectConceptFilterAndLabel': None,
#    'SubProjectConceptFilterAndLabelKey': None,
#    'SubProjectForRent': None,
#    'SubProjectForSale': None,
#    'Urls': None,
#    'CompletionDate': '2023-08-31T00:00:00Z',
#    'Address': 'Bratislava II | Hraničná, 82105 Bratislava',
#    'CmsFloorNumberOfTotalFloors': '7',
#    'CmsB2BProductItemSize': '28.2',
#    'CmsTransformerNumberOfRooms': '1',
#    'CmsTransformerNumberOfRuComRooms': None,
#    'CmsTransformerTotalAreaSize': '28,22',
#    'CmsTransformerKitchenSize': '0',
#    'CmsTransformerLivingAreaSize': '28,2',
#    'CmsTransformerPriceWhenFullPayment': '0',
#    'ApartmentId': '1-Q47YAF',
#    '_Locality': 'Bratislava',
#    '_AvailabilityStatusText': 'Nezáväzne rezervované',
#    '_AvailabilityStatusKey': 'Reserved',
#    '_AvailabilityStatusCssClass': 'reserved',
#    '_FloorPlanImageUrl': 'https://res.cloudinary.com/yit/image/upload/q_auto:eco,f_auto,fl_lossy,w_700,c_limit/v1629725196/374589.jpg',
#    '_FloorPlanLargeImageUrl': 'https://res.cloudinary.com/yit/image/upload/q_auto:eco,f_auto,fl_lossy,w_1920,c_limit/v1629725196/374589.jpg',
#    '_HasFloorPlan': True,
#    '_NextShowingText': None,
#    '_CampaignBadge': None,
#    '_ProjectBuildingTypes': 'Bytový dom',
#    '_Buttons': [],
#    '_Transformer': False,
#    '_Badges': [],
#    '_LayoutType': None}}]

# %%
apartment_data = []
project_data = []

scrapingDate = datetime.today().strftime('%Y-%m-%d')

for item in data:

    apartment_dict = {

        "ApartmentName": None,
        "ApartmentAddress": None,
        "NumberOfRooms": None,
        "AppartmentFloor" : None,
        "ApartmentSize": None,
        "TotalAreaSize": None,
        "BalconySize" : None,
        "ReservationStatus": None,
        "SalesPrice": None,
        "ScrapingDate": scrapingDate,
        "ProjectName": None,
        "ProjectID": None,
    }

    project_dict = {
        "ProjectName": None,
        "ProjectAddress":None,
        "ProjectTotalApartments": None,
        "ProjectAvailableApartments": None,
        "ScrapingDate": scrapingDate
    }  

    #Fill Apartment dict values
    try:
        apartment_dict['ApartmentName'] = item['Fields']['ApartmentNumber']
    except KeyError:
        pass

    try:
        apartment_dict['ApartmentAddress'] = item['Fields']['ApartmentAddress']
    except KeyError:
        pass

    try:
        apartment_dict['NumberOfRooms'] = item['Fields']['NumberOfRooms']
    except KeyError:
        pass

    try:
        apartment_dict['AppartmentFloor'] = item['Fields']['FloorNumber']
    except KeyError:
        pass

    try:
        apartment_dict['ApartmentSize'] = item['Fields']['ApartmentSize']
    except KeyError:
        pass

    try:
        apartment_dict['TotalAreaSize'] = item['Fields']['TotalAreaSize']
    except KeyError:
        pass

    try:
        apartment_dict['BalconySize'] = item['Fields']['BalconySize']
    except KeyError:
        pass

    try:
        apartment_dict['ReservationStatus'] = item['Fields']['ReservationStatus']
    except KeyError:
        pass

    try:
        apartment_dict['SalesPrice'] = item['Fields']['SalesPrice']
    except KeyError:
        pass

    try:
        apartment_dict['ProjectName'] = item['Fields']['ProjectMarketingName']
    except KeyError:
        pass

    # Fill Project dict values

    if not any(project['ProjectName'] == item['Fields']['ProjectMarketingName'] for project in project_data):
        try:
            project_dict['ProjectName'] = item['Fields']['ProjectMarketingName']
        except KeyError:
            pass
        
        try:
            project_dict['ProjectAddress'] = item['Fields']['Address']
        except KeyError:
            pass
        
        try:
            project_dict['ProjectTotalApartments'] = item['Fields']['ProjectNumberOfApartments']
        except KeyError:
            pass
        
        try:
            project_dict['ProjectAvailableApartments'] = 1
        except KeyError:
            pass

        project_data.append(project_dict)
    else:
        for index, project in enumerate(project_data):
            if project['ProjectName'] == item['Fields']['ProjectMarketingName']:
                project_data[index]['ProjectAvailableApartments'] = project_data[index]['ProjectAvailableApartments']+1
                break

        
    apartment_data.append(apartment_dict)

# %%
def findApartmentInDB(apartment):
    url = 'http://127.0.0.1:8000/apartments'
    db_apartments = requests.get(url).json()
    for db_apartment in db_apartments:
        if db_apartment['ApartmentName'] == apartment['ApartmentName']:
            return db_apartment
    return None

def getLastApartmentInDB():
    url = 'http://127.0.0.1:8000/apartment/last'
    db_apartment = requests.get(url).json()
    return db_apartment

def findTodaysStatus(apartment):
    apartment_id = apartment["ApartmentID"]
    today = datetime.today().strftime('%Y-%m-%d')
    url = f'http://127.0.0.1:8000/status/{apartment_id}/{today}'
    response = requests.get(url)
    if(response.status_code == 200):
        db_status = response.json()
        return db_status
    return None

def findProjectInDB(project):
    url = 'http://127.0.0.1:8000/projects'
    db_projects = requests.get(url).json()
    for db_project in db_projects:
        if db_project['ProjectName'] == project['ProjectName']:
            print(db_project)
            return db_project
    return None

def findProjectID(project_name):
    url = 'http://127.0.0.1:8000/projects'
    db_projects = requests.get(url).json()
    for db_project in db_projects:
        if db_project['ProjectName'] == project_name:
            return db_project['ProjectID']
    return -1

def getLastProjectInDB():
    url = 'http://127.0.0.1:8000/project/last'
    db_project = requests.get(url).json()
    return db_project

def findTodaysAvailability(project):
    project_id = project["ProjectID"]
    today = datetime.today().strftime('%Y-%m-%d')
    url = f'http://127.0.0.1:8000/availability/{project_id}/{today}'
    response = requests.get(url)
    if(response.status_code == 200):
        db_availabilities = response.json()
        return db_availabilities
    return None

postApartmentUrl = 'http://127.0.0.1:8000/apartments'
statusUrl = 'http://127.0.0.1:8000/status'
postProjectUrl = 'http://127.0.0.1:8000/projects'
availabilityUrl = 'http://127.0.0.1:8000/availability'

# %%
for project in project_data:
    db_project = findProjectInDB(project) 
    if db_project != None: #if the project is already in the db
        db_projectAvailability = findTodaysAvailability(db_project)
        if db_projectAvailability != None: #if there is a availability for today in db - update its values
            updated_availability={
                'Project': db_project['ProjectID'],
                'ProjectAvailableApartments': project['ProjectAvailableApartments'],
                'ScrapingDate': project['ScrapingDate']           
            }
            response = requests.put(availabilityUrl, json = updated_availability)
            if(response.status_code == 200):
                print(f"Successfully updated availability for project: {db_project['ProjectName']}")
            else:
                print(f"Failed to update availability for project: {project['ProjectName']}")
        else: #if there is no availability in the db for today
            availability={
                'Project': db_project['ProjectID'],
                'ProjectAvailableApartments': project['ProjectAvailableApartments'],
                'ScrapingDate': project['ScrapingDate']        
            }
            response = requests.post(availabilityUrl, json = availability)
            if(response.status_code == 200):
                print(f"Successfully input todays availability for project: {db_project['ProjectName']}")
            else:
                print(f"Failed to input todays availability for project: {project['ProjectName']}")
    else: #if the project is not yet in the db
        projectData = {
            "ProjectName": project['ProjectName'],
            "ProjectAddress": project['ProjectAddress'],
            "ProjectTotalApartments": project['ProjectTotalApartments'],
            "ScrapingDate": project['ScrapingDate']
        }
        response = requests.post(postProjectUrl, json = projectData)
        if(response.status_code == 200):
            last_project = getLastProjectInDB()
            availability={
                'Project': last_project['ProjectID'],
                'ProjectAvailableApartments': project['ProjectAvailableApartments'],
                'ScrapingDate': project['ScrapingDate']
            }
            response = requests.post(availabilityUrl, json = availability)
            if(response.status_code == 200):
                print(f"Successfully input project: {project['ProjectName']}, and accompanying availability")
            else:
                print(f"Successfully input project: {project['ProjectName']}, but NOT the availability")
        else:
            print(f"Failed to imput project: {project['ProjectName']}")
# Out:
# {'ProjectID': 9, 'ProjectName': 'NUPPU - Orkidea', 'ProjectAddress': 'Bratislava II | Hraničná 28, 28A, 28B, 82105 bratislava', 'ProjectTotalApartments': 98, 'ScrapingDate': '2021-12-06'}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15704/49886506.py in <module>
#       2     db_project = findProjectInDB(project)
#       3     if db_project != None: #if the project is already in the db
# ----> 4         db_projectAvailability = findTodaysAvailability(db_project)
#       5         if db_projectAvailability != None: #if there is a availability for today in db - update its values
#       6             updated_availability={
#
# ~\AppData\Local\Temp/ipykernel_15704/864692773.py in findTodaysAvailability(project)
#      56         db_availabilities = response.json()
#      57         for db_availability in db_availabilities:
# ---> 58             if db_availability['ProjectName'] == project['ProjectName']:
#      59                 return db_availability
#      60     return None
#
# TypeError: string indices must be integers

# %%
for apartment in apartment_data:
    db_apartment = findApartmentInDB(apartment)
    if db_apartment != None: #if the apartment is alreadI y in the db
        db_apartmentStatus = findTodaysStatus(db_apartment)
        if db_apartmentStatus != None: #if there is a status for today in db - update its values
            updated_status={
                'Apartment': db_apartment['ApartmentID'],
                'ReservationStatus': apartment['ReservationStatus'],
                'SalesPrice': apartment['SalesPrice'],
                'ScrapingDate': apartment['ScrapingDate'],           
            }
            response = requests.put(statusUrl, json = updated_status)
            if(response.status_code == 200):
                print(f"Successfully updated status for apartment: {db_apartment['ApartmentName']}")
            else:
                print(f"Failed to update status for apartment: {apartment['ApartmentName']}")
        else: #if there is no status in the db for today
            status={
                'Apartment': db_apartment['ApartmentID'],
                'ReservationStatus': apartment['ReservationStatus'],
                'SalesPrice': apartment['SalesPrice'],
                'ScrapingDate': apartment['ScrapingDate'],           
            }
            response = requests.post(statusUrl, json = status)
            if(response.status_code == 200):
                print(response.content)
                print(f"Successfully input todays status for apartment: {db_apartment['ApartmentName']}")
            else:
                print(f"Failed to input todays status for apartment: {apartment['ApartmentName']}")
    else: #if the apartment is not yet in the db
        apartmentData = {
            'ApartmentName': apartment['ApartmentName'],
            'ApartmentAddress': apartment['ApartmentAddress'],
            'NumberOfRooms': apartment['NumberOfRooms'],
            'AppartmentFloor': apartment['AppartmentFloor'],
            'ApartmentSize': apartment['ApartmentSize'],
            'TotalAreaSize': apartment['TotalAreaSize'],
            'BalconySize': apartment['BalconySize'],
            'Project_id': findProjectID(apartment['ProjectName']),
            'ScrapingDate': apartment['ScrapingDate']
        }
        print(apartmentData)
        response = requests.post(postApartmentUrl, json = apartmentData)
        if(response.status_code == 200):
            last_apartment = getLastApartmentInDB()
            status={
                'Apartment': last_apartment['ApartmentID'],
                'ReservationStatus': apartment['ReservationStatus'],
                'SalesPrice': apartment['SalesPrice'],
                'ScrapingDate': apartment['ScrapingDate']
            }
            print(response.content)
            break
            #response = requests.post(statusUrl, json = status)
            if(response.status_code == 200):
                print(f"Successfully input apartment: {apartment['ApartmentName']}, and accompanying status")
            else:
                print(f"Successfully input apartment: {apartment['ApartmentName']}, but NOT the status")
        else:
            print(f"Failed to imput apartment: {apartment['ApartmentName']}")
# Out:
# Successfully updated status for apartment: F 324
# Successfully updated status for apartment: F 175
# Successfully updated status for apartment: F 373
# {'ApartmentName': 'B3.24', 'ApartmentAddress': 'Svätoplukova B3.24', 'NumberOfRooms': '1', 'AppartmentFloor': '2.NP', 'ApartmentSize': 35.7, 'TotalAreaSize': 40.68, 'BalconySize': 4.98, 'Project_id': 10, 'ScrapingDate': '2021-12-06'}
# b'"Failed to Add"'

# %%
print("Script finished executing!")
